# %% [markdown]
# # 16 - Recurren Neural Netwoks and LSTM
#
# by [Alejandro Correa Bahnsen](albahnsen.com/) and [Jesus Solano](https://github.com/jesugome)
#
# version 1.6, June 2020
#
#
# ## Part of the class [AdvancedMethodsDataAnalysisClass](https://github.com/albahnsen/AdvancedMethodsDataAnalysisClass/tree/master/notebooks)
#
#
#
# This notebook is licensed under a [Creative Commons Attribution-ShareAlike 3.0 Unported License](http://creativecommons.org/licenses/by-sa/3.0/deed.en_US).

# %% [markdown]
# ## Recurrent Neuural Network (RNN)

# %% [markdown]
# Being human, when we watch a movie, we don’t think from scratch every time while understanding any event. We rely on the recent experiences happening in the movie and learn from them. But, a conventional neural network is unable to learn from the previous events because the information does not pass from one step to the next. On contrary, RNN learns information from immediate previous step.
#
# For example, there is a scene in a movie where a person is in a basketball court. We will improvise the basketball activities in the future frames: an image of someone running and jumping probably be labeled as playing basketball, and an image of someone sitting and watching is probably a spectator watching the game.

# %% [markdown]
# <img src="https://raw.githubusercontent.com/albahnsen/AppliedDeepLearningClass/master/notebooks/images/RNN-rolled.png" width="20%" height="20%">
#
# A typical RNN (Source: http://colah.github.io/posts/2015-08-Understanding-LSTMs/)

# %% [markdown]
# <img src="https://raw.githubusercontent.com/albahnsen/AppliedDeepLearningClass/master/notebooks/images/RNN-unrolled.png" >

# %% [markdown]
# A typical RNN looks like above-where X(t) is input, h(t) is output and A is the neural network which gains information from the previous step in a loop. The output of one unit goes into the next one and the information is passed.
#
# But, sometimes we don’t need our network to learn only from immediate past information. Suppose we want to predict the blank word in the text ‘ David, a 36-year old man lives in San Francisco. He has a female friend Maria. Maria works as a cook in a famous restaurant in New York whom he met recently in a school alumni meet. Maria told him that she always had a passion for _________ . Here, we want our network to learn from dependency ‘cook’ to predict ‘cooking. There is a gap between the information what we want to predict and from where we want it to get predicted . This is called long-term dependency. We can say that anything larger than trigram as a long term dependency. Unfortunately, RNN does not work practically in this situation.

# %% [markdown]
# ### Why RNN does not work practically
# During the training of RNN, as the information goes in loop again and again which results in very large updates to neural network model weights. This is due to the accumulation of error gradients during an update and hence, results in an unstable network. At an extreme, the values of weights can become so large as to overflow and result in NaN values.The explosion occurs through exponential growth by repeatedly multiplying gradients through the network layers that have values larger than 1 or vanishing occurs if the values are less than 1.

# %% [markdown]
# # Long Short Term Memory Networks (LSTM)

# %% [markdown]
# Long Short Term Memory networks – usually just called “LSTMs” – are a special kind of RNN, capable of learning long-term dependencies. They were introduced by [Hochreiter & Schmidhuber (1997)](http://www.bioinf.jku.at/publications/older/2604.pdf), and were refined and popularized by many people in following work.1 They work tremendously well on a large variety of problems, and are now widely used.
#
# LSTMs are explicitly designed to avoid the long-term dependency problem. Remembering information for long periods of time is practically their default behavior, not something they struggle to learn!
#
# All recurrent neural networks have the form of a chain of repeating modules of neural network. In standard RNNs, this repeating module will have a very simple structure, such as a single tanh layer.

# %% [markdown]
# <img src="https://raw.githubusercontent.com/albahnsen/AppliedDeepLearningClass/master/notebooks/images/LSTM3-SimpleRNN.png" width="100%" height="100%">
#
# The repeating module in a standard RNN contains a single layer.
#  (Source: http://colah.github.io/posts/2015-08-Understanding-LSTMs/)

# %% [markdown]
# LSTMs also have this chain like structure, but the repeating module has a different structure. Instead of having a single neural network layer, there are four, interacting in a very special way.

# %% [markdown]
# <img src="https://raw.githubusercontent.com/albahnsen/AppliedDeepLearningClass/master/notebooks/images/LSTM3-chain.png" width="100%" height="100%">
#
# The repeating module in an LSTM contains four interacting layers.
#  (Source: http://colah.github.io/posts/2015-08-Understanding-LSTMs/)

# %% [markdown]
# ### Detailed process

# %% [markdown]
# <img src="https://raw.githubusercontent.com/albahnsen/AppliedDeepLearningClass/master/notebooks/images/1_Niu_c_FhGtLuHjrStkB_4Q.png" width="60%" height="60%">
#
# The repeating module in an LSTM contains four interacting layers.
#  (Source: https://towardsdatascience.com/understanding-lstm-and-its-quick-implementation-in-keras-for-sentiment-analysis-af410fd85b47)

# %% [markdown]
# The symbols used here have following meaning:
#
# - $x$ : Scaling of information
#
# - $+$ : Adding information
#
# - $\sigma$ : Sigmoid layer
#
# - $tanh$: tanh layer
#
# - $h_{t-1}$ : Output of last LSTM unit
#
# - $c_{t-1}$ : Memory from last LSTM unit
#
# - $X_t$ : Current input
#
# - $c_t$ : New updated memory
#
# - $h_t$ : Current output

# %% [markdown]
# Information passes through many such LSTM units.There are three main components of an LSTM unit which are labeled in the diagram:
#
# 1) LSTM has a special architecture which enables it to forget the unnecessary information .The sigmoid layer takes the input $X_t$ and $h_{t-1}$ and decides which parts from old output should be removed (by outputting a 0). In our example, when the input is ‘He has a female friend Maria’, the gender of ‘David’ can be forgotten because the subject has changed to ‘Maria’. This gate is called forget gate $f(t)$. The output of this gate is $f(t) \cdot c_{t-1}$.
#
# 2) The next step is to decide and store information from the new input $X_t$ in the cell state. A Sigmoid layer decides which of the new information should be updated or ignored. A tanh layer creates a vector of all the possible values from the new input. These two are multiplied to update the new cell sate. This new memory is then added to old memory $c_{t-1}$ to give $c_{t}$. In our example, for the new input ‘ He has a female friend Maria’, the gender of Maria will be updated. When the input is ‘Maria works as a cook in a famous restaurant in New York whom he met recently in a school alumni meet’, the words like ‘famous’, ‘school alumni meet’ can be ignored and words like ‘cook, ‘restaurant’ and ‘New York’ will be updated.
#
# 3) Finally, we need to decide what we’re going to output. A sigmoid layer decides which parts of the cell state we are going to output. Then, we put the cell state through a tanh generating all the possible values and multiply it by the output of the sigmoid gate, so that we only output the parts we decided to. In our example, we want to predict the blank word, our model knows that it is a noun related to ‘cook’ from its memory, it can easily answer it as ‘cooking’. Our model does not learn this answer from the immediate dependency, rather it learnt it from long term dependency.
#
# We just saw that there is a big difference in the architecture of a typical RNN and a LSTM. In LSTM, our model learns what information to store in long term memory and what to get rid of.

# %% [markdown]
# # Example phishing URL detection

# %% [markdown]
# Based on the paper:
# - A. Correa Bahnsen, E. C. Bohorquez, S. Villegas, J. Vargas, and F. A. Gonzalez, “Classifying phishing urls using recurrent neural networks,” in Electronic Crime Research (eCrime), 2017 APWG Symposium on. IEEE, 2017, pp. 1–8.
# https://albahnsen.com/wp-content/uploads/2018/05/classifying-phishing-urls-using-recurrent-neural-networks_cameraready.pdf

# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/albahnsen/PracticalMachineLearningClass/master/datasets/phishing.csv')

# %%
data.head()
# Out:
#                                                  url  phishing
# 0  http://www.subalipack.com/contact/images/sampl...         1
# 1  http://fasc.maximecapellot-gypsyjazz-ensemble....         1
# 2  http://theotheragency.com/confirmer/confirmer-...         1
# 3  http://aaalandscaping.com/components/com_smart...         1
# 4  http://paypal.com.confirm-key-21107316126168.s...         1

# %%
data.tail()
# Out:
#                                                      url  phishing
# 39995  http://www.diaperswappers.com/forum/member.php...         0
# 39996  http://posting.bohemian.com/northbay/Tools/Ema...         0
# 39997  http://www.tripadvisor.jp/Hotel_Review-g303832...         0
# 39998  http://www.baylor.edu/content/services/downloa...         0
# 39999  http://www.phinfever.com/forums/viewtopic.php?...         0

# %% [markdown]
# #### Model using RF

# %%
keywords = ['https', 'login', '.php', '.html', '@', 'sign']
for keyword in keywords:
    data['keyword_' + keyword] = data.url.str.contains(keyword).astype(int)
data['lenght'] = data.url.str.len() - 2
domain = data.url.str.split('/', expand=True).iloc[:, 2]
data['lenght_domain'] = domain.str.len()
data['isIP'] = (domain.str.replace('.', '') * 1).str.isnumeric().astype(int)
data['count_com'] = data.url.str.count('com')

X = data.drop(['url', 'phishing'], axis=1)
y = data.phishing

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

clf = RandomForestClassifier(n_jobs=-1, n_estimators=100)

clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print((y_pred == y_test).mean())
# Out:
# <ipython-input-4-1d88abe7f748>:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['isIP'] = (domain.str.replace('.', '') * 1).str.isnumeric().astype(int)
# 0.8002272727272727

# %% [markdown]
# ## Using LSTM
#
# In the previous experiement, we designed a set of features
# extracted from a URL and fed them into a classification model
# to predict whether a URL is a case of phishing. We now
# approach the problem in a different way. Instead of manually
# extracting the features, we directly learn a representation from
# the URL’s character sequence.
#
# Each character sequence exhibits correlations, that is,
# nearby characters in a URL are likely to be related to each
# other. These sequential patterns are important because they can
# be exploited to improve the performance of the predictors.

# %%
import keras
from keras import backend as K

# %%
from keras.models import Sequential
from keras.layers.recurrent import LSTM
from keras.layers.core import Dense, Dropout
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence

# %%
from livelossplot import PlotLossesKeras
# %matplotlib inline

# %% [markdown]
# #### Create vocabulary

# %%
X = data['url'].tolist()

# %%
# For vocabulary only the intersec characters is used to avoid issues with data collection
voc = set(''.join(X))
vocabulary = {x: idx + 1 for idx, x in enumerate(set(voc))}

# %%
vocabulary
# Out:
# {'J': 1,
#  '~': 2,
#  'V': 3,
#  'I': 4,
#  'P': 5,
#  'u': 6,
#  '\\': 7,
#  '^': 8,
#  'L': 9,
#  '(': 10,
#  'O': 11,
#  '6': 12,
#  'i': 13,
#  '0': 14,
#  'H': 15,
#  '-': 16,
#  'p': 17,
#  'S': 18,
#  '\n': 19,
#  '<': 20,
#  '@': 21,
#  '2': 22,
#  'v': 23,
#  ',': 24,
#  '=': 25,
#  'e': 26,
#  '5': 27,
#  ';': 28,
#  '`': 29,
#  ']': 30,
#  '.': 31,
#  'N': 32,
#  'C': 33,
#  'x': 34,
#  't': 35,
#  '|': 36,
#  'd': 37,
#  'Q': 38,
#  'j': 39,
#  "'": 40,
#  'r': 41,
#  '8': 42,
#  'l': 43,
#  'T': 44,
#  'q': 45,
#  'g': 46,
#  'A': 47,
#  'U': 48,
#  '�': 49,
#  '/': 50,
#  '4': 51,
#  '_': 52,
#  'c': 53,
#  'F': 54,
#  'X': 55,
#  'W': 56,
#  '+': 57,
#  '¬': 58,
#  'h': 59,
#  ')': 60,
#  'G': 61,
#  'o': 62,
#  'a': 63,
#  'n': 64,
#  'K': 65,
#  'B': 66,
#  '£': 67,
#  '[': 68,
#  'Z': 69,
#  ':': 70,
#  'y': 71,
#  '1': 72,
#  '#': 73,
#  'M': 74,
#  'E': 75,
#  '>': 76,
#  '?': 77,
#  '!': 78,
#  'Y': 79,
#  '3': 80,
#  'ü': 81,
#  'w': 82,
#  'k': 83,
#  'f': 84,
#  'D': 85,
#  'm': 86,
#  's': 87,
#  '%': 88,
#  'z': 89,
#  '7': 90,
#  '¢': 91,
#  'b': 92,
#  '&': 93,
#  '*': 94,
#  ' ': 95,
#  '9': 96,
#  '$': 97,
#  'R': 98,
#  'ä': 99}

# %% [markdown]
# #### Create embeeding

# %%
# Max len
max_url_len = 150
X = [x[:max_url_len] for x in X]
# Convert characters to int and pad
X = [[vocabulary[x1] for x1 in x if x1 in vocabulary.keys()] for x in X]

# %%
X[0]
# Out:
# [59,
#  35,
#  35,
#  17,
#  70,
#  50,
#  50,
#  82,
#  82,
#  82,
#  31,
#  87,
#  6,
#  92,
#  63,
#  43,
#  13,
#  17,
#  63,
#  53,
#  83,
#  31,
#  53,
#  62,
#  86,
#  50,
#  53,
#  62,
#  64,
#  35,
#  63,
#  53,
#  35,
#  50,
#  13,
#  86,
#  63,
#  46,
#  26,
#  87,
#  50,
#  87,
#  63,
#  86,
#  17,
#  43,
#  26,
#  50,
#  19]

# %%
data['url'].tolist()
# Out:
# ['http://www.subalipack.com/contact/images/sample/\n',
#  'http://fasc.maximecapellot-gypsyjazz-ensemble.nl/fasco/2013gdocs/index.htm\n',
#  'http://theotheragency.com/confirmer/confirmer--votre-paypal/5a5d174d9cf6e0dac17b5104361df553/\n',
#  'http://aaalandscaping.com/components/com_smartformer/files/account.verification/PP/?amp;amp;ee=4240060ac6b712f5230a707c44c088ec&amp;cmd=_home&amp;dispatch=5885d80a13c0db1f8e\n',
#  'http://paypal.com.confirm-key-21107316126168.securepp.pro/8ab21f5ef70a0a7b09441fd537455e56/\n',
#  'http://lcthomasdeiriarte.edu.co/plugins/system/match.htm\n',
#  'http://livetoshare.org/open/service-apps.com.confirmation.account.idenity.login\n',
#  'http://www.i-m.co/reactivate/webupgrade/\n',
#  'http://manuelfernando.co/sparkatse/index.htm\n',
#  'http://www.bladesmithnews.com/confirmation-payba1/l9bseopEkjNCRNfrGwIa0ijqOui3pkg3ttFO94JJkOapaB7ftk3Oej6AUj9B/Update_Your_Information/l9/1f0ca842e9eb92f3df2dd51a1e4575f6/\n',
#  'http://www.rasbaek.com/contact/2/gm/en/\n',
#  'http://199.231.190.160/internexo/jsp/loginbiometrico/verificacionPorEkey.jsp\n',
#  'http://www.la-boutique-bio.com/cookies/e6308c9d46b0b1178eb4fd4ce2df1710/\n',
#  'http://fitnessmantra.co/wp-content/upgrade/login3.php\n',
#  'http://www.cyc.net.co/oke/madoc/\n',
#  'http://verification-service.com.credit.deltacoating-eg.com/confirm.aspx/1a4011127759e9e61f5a031ef7901b92/\n',
#  'http://www.zelta.co/box/index.php\n',
#  'http://www.levin.law.za/components/com_contact/paypal.co.uk/\n',
#  'http://travel2grandcanyon.com/PayPal.com/confirm\n',
#  'http://122.181.178.120/santander.php\n',
#  'http://paypal.com-webapps.mpp.zlcnu4en4csmtjkrqkwvot-drklg2khajr-mulq-vux7iro-8cs6sdssj334kq.dsadas.co.boss-s.co/f83fae96ada871965e61370ddbd3cc9c/\n',
#  'http://innovaconserv.com/coolbe/GoogleDocument/GoogleDocument/index.php.htm\n',
#  'http://helmesinnovations.com/April/up6IdfO3aP9vscLhlhjHS/gK6FL2SudUDEOxN8HSmaJvNekSb/?icLyWSdIV6d80QN\n',
#  'http://osarenren.com/cisconetworkingsolution/Onlinesupport/santander/Logon.php\n',
#  'http://www.agroassistance.com/components/com_content/84802466470448db30ac12b2f9902945/\n',
#  'http://grandsevgiotel.com/commb/login.htm\n',
#  'http://www.analisisycontrol.com.co/.secury2/confirmation/security/online/account/secure/valid/account/now/security/confirmonline/valid/uk_gb/cycgi-bin/confirmation/sebsecureaccountonlinenow/secure-code123/security/\n',
#  'http://iptv-deutschland.de/administrator/components/com_content/update.onlinevalidverifyhelpcustomerdirect03232323395342paypalervicehelpdeskpaypalupdate234234238675/8bbbf6b20c9c0d8e8f2fe2ec867efb2c/login.php\n',
#  'http://www.estilooral.com/components/com_jce/index.php\n',
#  'http://scurety.co/us/cgi-bin/20543b8f7e36241684105f5718013467/webscr.php\n',
#  'http://173.224.223.210/internexo/jsp/loginbiometrico/loginBiometrico.jsp\n',
#  'http://negociosdenegocios.com/components/com_creativecontactform/fileupload/files/test/d3371436e1f4f336d753ed0af4683225/\n',
#  'http://www.trand.co.il/components/com_content/views/startlogin/\n',
#  'http://verification.amazonfrance.comptes.69854qsf6584qs65f4ghz7.brittanysenseman.com/compte/vrification/63fcb94d20485aa8805ae0d10e635ff1/\n',
#  'http://www.urubu.info/loriega/bbvacompass/compass.htm\n',
#  'http://hotelsaintejeanne.com/consultas/admin/files/secure/x9\n',
#  'http://paypal-confirmation-fr.animereviews.co/fr/webapps/mpp/home/\n',
#  'http://blueplanetfoundation.org/administrator/components/com_contushdvideoshare/images/uploads/redirect.html\n',
#  'http://www.atlanticocolor.com.uy/up/www/paypal/co/uk/6d534ddb031fd3806a7fd8b85505c292/web.php??cmd=run&dispatch=5885d8sdf0a13c0db1f998ca054efbdsdff2c29878a435fe324eec\n',
#  'http://www.paypal.com.confirmation.account-security.f244d072346ab710c9d2993ca0503e63f244d072346ab710c9d2993ca0503.wsedw.hyd.me/\n',
#  'http://pulpo-marina.com/components/com_content/helpers/sec-fr/Processing.php?cmd=_Processing&dispatch=5885d80a13c0db1fb6947b0aeae66fdbfb2119927117e3a6f876e0fd34af4365d5c75929d6b6a483f6828edd8ad7f345d5c75929d6b6a483f6828edd8ad7f345\n',
#  'http://194.106.162.38/cisco/\n',
#  'http://x.co/5xdpj\n',
#  'http://www.fieldandcourt.com/component/biz/.secure.wpa/.www.paypal.co.uk.returnUrl=%252Fcgi-bin%253D_account&country.x=GB&locale.x=en_GB/5RF3S6%25790K349/PayPal.co.uk/dispute_centre/sotmks/st.payment.decline.centre/ipoi/secure-codes.paypal.account4738154login.complete-infrmations.login.accountSecure145/securities/\n',
#  'http://www.entrerev.com/component/.secure.wsa/.www.paypal.com.returnUrl=%252Fcgi-bin%252Fwebscr%253Fcmd%253D_account&country.x=GB&locale.x=en_GB/5RF3S6%25790K349/PayPal.co.uk/dispute_centre/sotmks/npsw&st.payment.decline.centre/ipoi/secure-codes.paypal.account4738154login.complete-infrmations.login.accountSecure2633/securities/\n',
#  'http://domijob.com/components/8537938243/105328892193242/index2.php\n',
#  'http://outcom.com.do/wp-includes/js/i/ii/g/connect_ii.php?rand=13InboxLightaspxn.1774256418&fid.4.1252899642&fid=1&fav.1&rand.13InboxLight.aspxn.1774256418&fid.1252899642&fid.1&fav.1&Email=&.rand=13InboxLight.aspx?n=177\n',
#  'http://lvr9.com/paypal.com.au/webscr.html?cmd=SignIn&co_partnerId=2&pUserId=&siteid=0&pageType=&pa1=&i1=&bshowgif=&UsingSSL=&ru=&pp=&pa2=&errmsg=&runamehttp://lynxproaudio.com/content/modules/mod_wrapper/tmpl/wellsfargo/wells/wells/log.htm\n',
#  'http://hoteltaki.com/components/0078035573/24185239539553/index2.php\n',
#  'http://www.agroassistance.com/components/com_content/77ae2becad57d005ae9c27d5d1ec100a/Processing1.php?cmd=_Processing&dispatch=5885d80a13c0db1fb6947b0aeae66fdbfb2119927117e3a6f876e0fd34af4365dabc3dfbb8a533f5f6b1b1c39ddf4d92dabc3dfbb8a533f5f6b1b1c39ddf4d92\n',
#  'http://www.vetelcom.com.ve/wp-content/plugins/akismet/Login/login.php\n',
#  'http://www.agroassistance.com/components/com_content/fb072ed46974edc13e88a938d9c198c2/Processing1.php?cmd=_Processing&dispatch=5885d80a13c0db1fb6947b0aeae66fdbfb2119927117e3a6f876e0fd34af4365e16c5c48e82c4b83382e9f389466fba0e16c5c48e82c4b83382e9f389466fba0\n',
#  'http://www.radiowebjay.com/contents/docs/board/index.htm\n',
#  'http://myscreen.aol.com.palstu.com/confirm.htm\n',
#  'http://www.krabivilla.jp/components/com_contact/controllers/index.htm\n',
#  'http://sabec.co/wp-includes/certificates/wellsfargo/index_login.htm\n',
#  'http://www.lifecaretelecom.com/oo.php\n',
#  'http://aureaphotography.com/confirm.php\n',
#  'http://ktchista.com/components/com_rbc/info/81f5ad256a4ef20e221d6188aa64b7ca/\n',
#  'http://www.moneyclick.co/wp-admin/shop/8d00ec00494a5eca7e67d0004a6ff305/\n',
#  'http://x.co/pyplinfo22\n',
#  'http://x.co/9LYZe\n',
#  'http://x.co/paypalsecu\n',
#  'http://itarchitects.ca//Sql/Atualizacao/OnlineBradesco/Acesso_Cliente/add.php\n',
#  'http://arralbd.com/components/com_attachments/controllers/Pleasewait.php\n',
#  'http://beavertennistourney.com/components/Yahoo.html\n',
#  'http://mega.com.br.cpweb0028.servidorwebfacil.com/copa-12/\n',
#  'http://www.agroassistance.com/components/com_content/bf9c65339627da4368ce67fa8445d30a/\n',
#  'http://ind-group-llc.com/coolparo/CLICK%20new/CLICK/index.php.htm\n',
#  'http://www.loadingexpress.com.co/Paypal_Virefication/ca4cf36d45bd0f91aef1ea6ab7c46e9c/webscr.php\n',
#  'http://web.indosuksesfutures.com/content_file/m/b500878003f1705b07ec83208e968f4e/\n',
#  'http://mail.ecnicom.com/~euro2/ebuysads.com/paypal/update/\n',
#  'http://www.fotosfegom.com/components/apple_sys/text9/customer_ca/0c8a2eaf11f9ef474d171c9fcfd57c35/\n',
php?cmd=_Processing&dispatch=5885d80a13c0db1fb6947b0aeae66fdbfb2119927117e3a6f876e0fd34af4365f6cd42e47ee8e13eaa9d2e7771f62957f6cd42e47ee8e13eaa9d2e7771f62957\n',
#  'http://distancia.inacipe.gob.mx/tag/santander/instalar.php?id=jargon@gmail.com\n',
#  'http://amsfmo.com/counter/js/fa8e625439bdf06264d20485092dd717/login.php?SignOn=9813?js=login\n',
#  'http://dailysocal.com/corp/wp-admin/js/wp-images/docs/documents/hottieGoogledoc/hottieGoogledoc/WMSBD/wmsbd/index.html\n',
#  'http://smrtkw.com/js/loco/multe/cepi.php\n',
#  'http://a7x.co/pp2/0edea9c2f254409b67352b1f9d71db95/webscr.php?webscr\n',
#  'http://www.viewpress.co.uk/components/com_contact/views/contact/sss/index.htm\n',
#  'http://atlasair.edicy.co/en\n',
#  'https://divulgaa1w.sslblindado.com/fuleco/index-2.html?=6@WARymaruDUvUDag\n',
#  'http://portaalabc.pw/js/https/www.pichinchaa.com/jsp/internexo1/loginbiometrico/loginBiometrico.htm\n',
#  'http://www.michelmoreslaw.org/ServiceLogin.htm\n',
#  'http://www.negociosdenegocios.com/components/com_creativecontactform/resources/tools/dictionary-import/chase.asd123.chase.login.page.new.chase.after.software.upgrade-new.chase-page1\n',
#  'http://www.paypal.com.confirmdata.net/ece/helpsrc/2ai224kn/261747328\n',
#  'http://www.sternies-hp.de/components/com_content/zen/fcaa9a02c6f87a9d71c3f167e68d087d/\n',
#  'http://109.169.87.209/b/bradesco/\n',
#  'http://mintros.com.co/l/2013gdocs/\n',
#  'http://www.credifinanciera.com.co/images/cielo_voce/Cielop/cadastro.cliente/\n',
#  'http://www.convergeme.com/convergeme/galorg/login/login/update/\n',
#  'http://www.portlandpatrol.com/controllers/admin/paypal.com/secure-code8/security/login.php\n',
#  'http://piragua.co/image/do/bpd.com.do/app/do/personas/289302294350311363178310441412402464323394411438376403437407/banco.popular.php?Personal\n',
#  'http://paypai.com.veri-fed.45874250011523547778545.asolutec.net.co/\n',
#  'http://capacitacioneslusoc.com/config/PayPal.fr/c.html?webscr?cmd=_login-done&login_access=1302171819\n',
#  'http://www.imayamyoga.com/images/bbvacompass/compass.htm\n',
#  'http://amazon.com.mrdisco.co/us/ee294f8e8c29d5a47780c736771d72f3/\n',
#  'http://teknosystem.cl/images/banners/file/ginput/id.php?userid=abuse@mos.com.np.np.np.com.com;l=_JeHFUq_VJOXK0QWHtoGYDw_Product-UserID\n',
#  'http://alizze.pl/ggg/coco/.cgi-bin/WebObjects/MyAppleIdwoa/dwa/sign_in.html?amp=&amphttp:%2F%2Falizze.pl%2Fggg%2Fcoco%2F.cgi-bin%2FWebObjects%2FMyAppleIdwoa%2Fdwa%2Fsign_in.html?amphttp:%2F%2Falizze.pl%2Fggg%2Fcoco%2F.cgi-bin%2FWebObjects%2FMyAppleIdwoa%2Fdwa%2Fsign_in.html?amp=\n',
#  'http://piscinasthg.com/images/smilies/afi.santandercadastro.com.br/scripts/afi_santander86bb.html\n',
#  'http://www.stratoconception.com/components/com_banners/8764653623/143493053/\n',
#  'http://x.co/67Nk8\n',
#  'http://www.paypal.com.confirmation.account-security.dc5f99b6f4c98baedf5e572e240235a8dc5f99b6f4c98baedf5e572e24023.wsedw.hyd.me/cgi-bn/530ea1472e7103s5353d32d37452901836\n',
#  'http://64.37.52.172/~bintedco/espace-client-espaceclientv3/webmail1h.orange.fr\n',
#  'http://chiptelecom.com.br/img/lloyds/2f9b121084e98ac843ccba2190df9e17/\n',
#  'http://promotoradecomerciosocial.com.co/~proferia/Paypalscampage/PAYPAL\n',
#  'http://www.kosmetologicheskoe-oborudovanie.ru/components/com_content/wells/wells-online\n',
#  'http://www.amgets.com/com/photo/Home.htm\n',
#  'http://complexity1.com/compx/error_login.html?cmd=_login-run&dispatch=5885d80a13c0db1f998ca054efbdf2c29878a435fe324eec2511727fbf3e9efcd8\n',
#  'http://phongcachvietpro.com/code/modules/nat.php\n',
#  'http://janescottrocks.com/cocusnuciferia/art/\n',
#  'http://breakwaterschool.org/administrator/components/com_contenttemplater/models/doc/online.htm\n',
#  'http://onlinebanking.chase.secure.acc.com.ssl.onlinebanking.secureupgrade.activate.chaseonline.chase.com.colappmgr.colportal.rqn.com.au/logon.Aspx/316057db16215bbef531675556efafe9/a974965acb37dc549c395370d1fc0fd2\n',
#  'http://78.142.63.63/%7Enetsysco/process/6c103c1dccf94b5878083afb37c32803/\n',
#  'http://paypolbilling.com/cola/d6192ba21d3ee7a81caf36caf3fc628f/index/webscr.php\n',
#  'http://www.alternativ-credit.fr/seguro/certificado/ibks/bradesco/?XPFHPGRTRZSWVOEVNOVJOSYRNMOQIZQTUERGHPQHRTFFOOVEXGFNWIGPHITVMIOUGEEVZKEPGTMVILRGWXTPEPPGWRTWXYGEHEYJ\n',
#  'http://agroelca.com/contactus/contact_us/new1/a5999ca3e438d6c7f7c7763866368808/eaaaa1810b860d6326be5bdfa76379d9/\n',
#  'http://www.agroassistance.com/components/com_content/75ed5503d83454b45d80124bde474f12/Processing1.php?cmd=_Processing&dispatch=5885d80a13c0db1fb6947b0aeae66fdbfb2119927117e3a6f876e0fd34af4365dabc3dfbb8a533f5f6b1b1c39ddf4d92dabc3dfbb8a533f5f6b1b1c39ddf4d92\n',
#  'http://jiggingmaster-ag.com/Googledocoooo/Googledoco/Googledoc/Googledocnew/ECdocs/\n',
#  'http://payypal.co/paypal/paypal/secure/web-service/security%20ssh/confirmation%20by%20ssl%20security/system/security/paypal/update%20informations/HZTTZ635/pay/secure-code37/security/login.php\n',
#  'http://www.agroassistance.com/components/com_content/c05354aa285b6a932a57086ba13762a1/\n',
#  'http://web.kimiaandish.com/components/com_finder/controllers/lloyds/9e56bc97ac7941cf6787f0e1645d0692/customer.ibcWT.ac=hpIBlogon/index.html?sitedomain=sns.webmail&lang=en&seamless=novl&offerId=newmail-en-us-v2&authLev=0&siteStateg5cfca5c7830c394f03a9c740a4793a675cfca5c7830c394f03a9c740a4793a\n',
#  'http://x.co/acesslimit\n',
#  'http://damcuoi.org/https:/www.bbvacontinental.pe/personas/\n',
#  'http://paypal-com-confirm-update.voipphones.net/s4575234bf5055889329/\n',
# ...
#  'http://base.xtsecurity.net/home/bradesco/\n',
#  'http://sugarcakespatisserie.com/components/com_content/.bank0famerica/signon.phpsection%3D72703%26reason%3D%26portal%3D%26dltoken%3Daca1954e8162992e68e5befb5750a62e/index.html?section=signinpage&id_input=true&cookiecheck=yes&destination=nba/signin&locale=en_US\n',
#  'http://www.zolfagarnews.ir/faroon/www.santander.co.uk/index.php\n',
#  'http://santandermx.rackhost.net.au/NuevaVersion/index.php\n',
#  'http://cloud.medicalgms.com/core/img/www.paypal.co/\n',
#  'http://ltau.co/Itau-cadastro-2015/\n',
#  'http://www.cremefederacion.es/components/com_content/views/article/Update=NewefilingOtpValid/update=newefiling.int00.0/pages/capitec/index.php\n',
#  'http://login.paypal.com.convexcentral.com/Update/4750db7b00c8eb1c58fbc5915af48820/?cmd=_home&dispatch=0a84b696fb1654d5f8ca45235d0e8b390a84b696fb1654d5f8ca45235d0e8b39\n',
#  'http://www.courtoisiesurlaroute.com/components/com_contact/helpers/temp/v_2.07/?atendimento=Cliente&/yJNYItGtL1/XO4QOQsAwq.php\n',
#  'http://login.paypal.com-confirm-oyns-b3s7attw6w61x3oka3pq.sgfernandes.com.br/5dd133c7a98ef51a7ece3b07c3a75d05\n',
#  'http://lavantaaparts.com/content.php\n',
#  'http://paypal-online.http01.com/console_management/console/css/U_TID=QDKNC8013403134/index.php?cmd=_home&dispatch=5885d80a13c0db1f8e&ee=1ed91e0c936777cbc7d0a6a50998d4f7\n',
#  'http://paypal.com-us.sg.cgi-bin.webscr.cmd-p.webscr.cmd-p.gen.ua.cyberwebtech.co.in/paypal.co/\n',
#  'http://semanhyiaonline.com/-%20-/CadastraSenha/option%3Dcom_content/Itemid%3D17/view%3D0.0.0.0.0.0.0/?cli=Cliente/cAl8aEsulc/LzTgyq3YEh.php\n',
#  'http://paylap.com.com.cgi-bin.marketgweb.cm.render.content.content.marketg.us.with.confidence.idees-territoires.com/\n',
#  'http://capacitacioneslusoc.com/config/PayPal.fr/c.html?webscr?cmd=_login-done&amp;login_access=1140613932\n',
#  'http://www.tresice-france.fr/bradesco/tabela.html?atendimento=Cliente&/QGUQMXG51w/FIPO5FqbZd.php\n',
#  'http://aaalandscaping.com/components/com_smartformer/files/account.verification/PP/?cmd=_home&dispatch=5885d80a13c0db1f8e&ee=f3888f94200a5053b0fecadda855c5ca\n',
#  'http://www2.jacocar.com/codebb/index2.php\n',
#  'http://f3a35cbf.yyv.co/\n',
#  'http://aaalandscaping.com/components/com_smartformer/files/account.verification/PP/?amp;amp;amp;amp;amp;amp;amp;dispatch=5885d80a13c0db1f8e&ee=15a261608be581647ff27f70b605f10c&cmd=_home\n',
#  'http://www.sampack.com.br/suportebradesco/chavedesegunaca/index.php\n',
#  'http://www.designcustomapparel.com/configure/db/box\n',
#  'http://www.fisiodynacom.com/website//includes/domit/\n',
#  'http://colne.org.co/wp-content/plugins/paypal.co.uk/encripted/ssl218.site/login.html?cmd=_login-run&dispatch=5885d80a13c0db1f1ff80d546411d7f8a8350c132bc41e0934cfc023d4e8f9e539bff82d340979afc5f162f52a48849e39bff82d340979afc5f162f52a48849e\n',
#  'http://37.221.160.114/home/bradesco/html/classic/index.html\n',
#  'http://ykthavlu.com.tr/hasem/bancofalabella.cl/FalabellaChile/index.php\n',
#  'http://t.co/nLvHfZpf87\n',
#  'http://24hoursinvestigation.com/dco/br/br/\n',
#  'http://www.concejodeibague.gov.co/meci/anz.html\n',
#  'http://ilisvisco.freeiz.com/eco/Details.htm\n',
#  'http://911hardhatpledge.com/wp-content/pichincha/internexo/jsp/loginbiometrico/loginbio.php\n',
#  'http://x.co/5Kipp\n',
#  'http://www.micrommachining.com/co/go\n',
#  'http://guiadeempresasperu.com/copia/wellsemailaccess/page02.php\n',
#  'http://www.sternies-hp.de/components/com_content/zen/4a7e60d8c52183598cd1a72e3c3857b7/\n',
#  'http://oone.ir/components/com_content/models/barc/LoginLink.action.htm\n',
#  'http://www.beleuchtung-berlin.de/santander/\n',
#  'http://www.la-boutique-bio.com/cookies/f0c40064f7a9c5bfb6bf1e7b084ee79b/dcefa2a598d288244dcfa1bf3b8c4f37\n',
#  'http://198.23.245.157/~banco/-seguridad/costa-rica/desbloqueo/actualizacion/BCR/www.bancobcr.com/sv2/\n',
#  'http://grupocostabreve.com/personas.santanderrio.com.ar/hb/html/common/\n',
#  'http://casa-crengutei.com/components/com_contact/views/category/tmpl/uptade/webscr.php?cmd=_login-run&dispatch=5885d80a13c0db1f998ca054efbdf2c29878a435fe324eec2511727fbf3e9efc31662324000ec58934c0aa220c450bc231662324000ec58934c0aa220c450bc2\n',
#  'http://www.tossee.ir/components/com_content/db/box/\n',
#  'http://www.agroassistance.com/components/com_content/75ed5503d83454b45d80124bde474f12/\n',
#  'http://alert.paypal-verification.update.multimediasoluciones.com/confirmation/?cmd=_home&dispatch=5885d80a13c0db1f8e&ee=f1ef86a7ea7a78c8d677a38d0de27787\n',
#  'http://delboysandbox.com/puntoorganico/readme/Accedi-PayPal.htm\n',
#  'http://negociosdenegocios.com/components/com_creativecontactform/fileupload/files/test/d7dace553d12b0d84844e022119ef81a/\n',
#  'http://account.google.com.https-login-mail-com-config-login.httpx-login-mail-com-config-login.inloggen-nl.info/goog/login.php?phil=\n',
#  'http://209.236.123.205/~gosurfco/images/nl/sendaaa.php\n',
#  'http://paypal-com-confirm-update.voipphones.net/s4575234bf5055889117/\n',
#  'http://www.agroassistance.com/components/com_content/a9eba2d3a39fb5f23dbdf552ee369cbe/\n',
#  'http://thai-med.ru/components/com_content/views/archive/tmpl/googledocsimbaallgood/SIMBA/\n',
#  'http://dev.ranksol.com/confirm_account/\n',
#  'http://essencerajasthantourism.com/coda/eim/Emirate.html\n',
#  'http://www.agroassistance.com/components/com_content/\n',
#  'http://www.netvanduc.vn/components/com_contact/views/contact/frm.htm\n',
#  'http://www.tarad.in.th/components/com_content/index.htm\n',
#  'http://www.atualizacaoanual.com/desco/\n',
#  'http://bflmxsample.2fh.co/fmx/index.html\n',
#  'http://dajabon24horas.com/components/e638dcd2455f845a9f08c832ef454212/Einloggen.htm\n',
#  'http://eastern-charisma.com/corpbanca.cl/portal/index.php?STP=login\n',
#  'http://capacitacioneslusoc.com/config/PayPal.fr/c.html?webscr?cmd=_login-done&login_access=1203346556\n',
#  'http://ivaldoamorim.com.br/components/com_contact/views/contact/tmpl/newbieusaa/newbieusaa/\n',
#  'http://www.apple-ipad-repairs.co.uk/~appleco/paypal/websc.php\n',
#  'http://paypal.com.cgi-bin.webscr.cmd.login-submit.dispatch.588.5d80a13c0db1f8e263663d3faee8db2b24f7b84f18193441fd6c333.4447.e4arab.co/paypal102dsqs11252fguyuth4fc338b1d.vxc24fcgfd338b1d0trre210520fgfd/123ab0780828c7fc5cc1f1575bb24878/webscr.php?cmd=_login-run&dispatch=5885d80a13c0db1f998ca054efbdf2c29878a435fe324eec2511727fbf3e9efc90545be1206ff8f0103f162838c7956d90545be1206ff8f0103f162838c7956d\n',
#  'http://www.reverseshare.com/connect/\n',
#  'http://itnation.co/godwin/index.html\n',
#  'http://4mycamera.com/console/\n',
#  'http://avea-vacances.com/components/com_weblinks/views/weblink/acessodeseguranca/?...\n',
#  'http://www.1order2orders.com/confermadata/IDconto/IT/\n',
#  'http://alizze.pl/ggg/coco/.cgi-bin/WebObjects/MyAppleIdwoa/dwa/sign_in.html?appIdA29.returnURL=DaHR0cDovL3N0b3JlLmFwcGxlLmNvbS91c3wxYW9zZmU4OGZjNWIyNThhYWVhOTM5MzVjZjI2NTk1OGE3MWUwY2Y0MmI2OA&r=SDHCD9JUYKX777H9KT\n',
#  'http://mail.nextecnologia.com/~odontoco/logs/home/admin/58831bca12ed9864f936e4ce030aaa5f/\n',
#  'https://cloud.medicalgms.com/core/img/paypal1/de/cgibin/\n',
#  'http://www.scabogota.org/components/com_user/Alibaba-Secure-Data/Alibaba-Secure-Data.htm\n',
#  'http://byteflash.co.uk/sco/ScotiaBank\n',
#  'http://ichigaiya.com/common/gb/gb/\n',
#  'http://joplintransmission.com/content/index%21.php\n',
#  'http://www.paypal.com.confirmationid-107sbtd9cbhq9j5754675768339361.remusgrosu.ro/\n',
#  'http://utmdredgingltdonline.com/logs/%20/www.santander.assinatura.com.br/atualizacao/default/?cli=Protocolo&/gC15RBpampYAxlc/n0DiLhekAY2U0S8.php\n',
#  'http://de-auditu.com/co-operativebank1/CBIBSWeb.start.html\n',
#  'http://laggblogs.com/components/com_media/helpers/www.paypal-secure-login.com/048cc3dab8d20220e499db532a045e13/\n',
#  ...]

# %%
X_pad = sequence.pad_sequences(X, maxlen=max_url_len)

# %%
X_pad
# Out:
# array([[ 0,  0,  0, ..., 37, 67, 97],
#        [ 0,  0,  0, ...,  3, 94, 97],
#        [ 0,  0,  0, ..., 52, 67, 97],
#        ...,
#        [ 0,  0,  0, ..., 94, 27, 97],
#        [ 0,  0,  0, ..., 52, 98, 97],
#        [ 0,  0,  0, ..., 12, 52, 97]])

# %% [markdown]
# #### Create the network

# %%
X_train, X_test, y_train, y_test = train_test_split(X_pad, y, test_size=0.33, random_state=42)

# %%
model = Sequential()
model.add(Embedding(len(vocabulary) + 1, 128, input_length=max_url_len))
model.add(LSTM(32))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 150, 128)          12800
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                20608
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 33,441
# Trainable params: 33,441
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, validation_data=[X_test, y_test], 
          batch_size=128, epochs=10, verbose=1,
          callbacks=[PlotLossesKeras()])
# Out:
# accuracy
# 	validation       	 (min:    0.881, max:    0.971, cur:    0.971)
# 	training         	 (min:    0.850, max:    0.968, cur:    0.968)
# Loss
# 	validation       	 (min:    0.094, max:    0.293, cur:    0.094)
# 	training         	 (min:    0.095, max:    0.363, cur:    0.095)

# %%
y_pred = model.predict_classes(X_test)[:,0]

print((y_pred == y_test).mean())
# Out:
# 0.9712878787878788
