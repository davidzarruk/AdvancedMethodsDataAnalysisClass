# %% [markdown]
# # 12 - Natural Language Processing
#
# by [Alejandro Correa Bahnsen](http://www.albahnsen.com/) and [Jesus Solano](https://github.com/jesugome)
#
# version 1.6, June 2020
#
# ## Part of the class [Practical Machine Learning](https://github.com/albahnsen/PracticalMachineLearningClass)
#
# This notebook is licensed under a [Creative Commons Attribution-ShareAlike 3.0 Unported License](http://creativecommons.org/licenses/by-sa/3.0/deed.en_US). Special thanks goes to [Kevin Markham](https://github.com/justmarkham)

# %% [markdown]
# ### What is NLP?
#
# - Using computers to process (analyze, understand, generate) natural human languages
# - Most knowledge created by humans is unstructured text, and we need a way to make sense of it
# - Build probabilistic model using data about a language
#
# ### What are some of the higher level task areas?
#
# - **Information retrieval**: Find relevant results and similar results
#     - [Google](https://www.google.com/)
# - **Information extraction**: Structured information from unstructured documents
#     - [Events from Gmail](https://support.google.com/calendar/answer/6084018?hl=en)
# - **Machine translation**: One language to another
#     - [Google Translate](https://translate.google.com/)
# - **Text simplification**: Preserve the meaning of text, but simplify the grammar and vocabulary
#     - [Rewordify](https://rewordify.com/)
#     - [Simple English Wikipedia](https://simple.wikipedia.org/wiki/Main_Page)
# - **Predictive text input**: Faster or easier typing
#     - [My application](https://justmarkham.shinyapps.io/textprediction/)
#     - [A much better application](https://farsite.shinyapps.io/swiftkey-cap/)
# - **Sentiment analysis**: Attitude of speaker
#     - [Hater News](http://haternews.herokuapp.com/)
# - **Automatic summarization**: Extractive or abstractive summarization
#     - [autotldr](https://www.reddit.com/r/technology/comments/35brc8/21_million_people_still_use_aol_dialup/cr2zzj0)
# - **Natural Language Generation**: Generate text from data
#     - [How a computer describes a sports match](http://www.bbc.com/news/technology-34204052)
#     - [Publishers withdraw more than 120 gibberish papers](http://www.nature.com/news/publishers-withdraw-more-than-120-gibberish-papers-1.14763)
# - **Speech recognition and generation**: Speech-to-text, text-to-speech
#     - [Google's Web Speech API demo](https://www.google.com/intl/en/chrome/demos/speech.html)
#     - [Vocalware Text-to-Speech demo](https://www.vocalware.com/index/demo)
# - **Question answering**: Determine the intent of the question, match query with knowledge base, evaluate hypotheses
#     - [How did supercomputer Watson beat Jeopardy champion Ken Jennings?](http://blog.ted.com/how-did-supercomputer-watson-beat-jeopardy-champion-ken-jennings-experts-discuss/)
#     - [IBM's Watson Trivia Challenge](http://www.nytimes.com/interactive/2010/06/16/magazine/watson-trivia-game.html)
#     - [The AI Behind Watson](http://www.aaai.org/Magazine/Watson/watson.php)
#
# ### What are some of the lower level components?
#
# - **Tokenization**: breaking text into tokens (words, sentences, n-grams)
# - **Stopword removal**: a/an/the
# - **Stemming and lemmatization**: root word
# - **TF-IDF**: word importance
# - **Part-of-speech tagging**: noun/verb/adjective
# - **Named entity recognition**: person/organization/location
# - **Spelling correction**: "New Yrok City"
# - **Word sense disambiguation**: "buy a mouse"
# - **Segmentation**: "New York City subway"
# - **Language detection**: "translate this page"
# - **Machine learning**
#
# ### Why is NLP hard?
#
# - **Ambiguity**:
#     - Hospitals are Sued by 7 Foot Doctors
#     - Juvenile Court to Try Shooting Defendant
#     - Local High School Dropouts Cut in Half
# - **Non-standard English**: text messages
# - **Idioms**: "throw in the towel"
# - **Newly coined words**: "retweet"
# - **Tricky entity names**: "Where is A Bug's Life playing?"
# - **World knowledge**: "Mary and Sue are sisters", "Mary and Sue are mothers"
#
# NLP requires an understanding of the **language** and the **world**.

# %% [markdown]
# # Data

# %%
import pandas as pd
import numpy as np
import scipy as sp
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
# from textblob import TextBlob, Word
from nltk.stem.snowball import SnowballStemmer
# %matplotlib inline

# %%
df = pd.read_csv('https://github.com/albahnsen/PracticalMachineLearningClass/raw/master/datasets/mashable_texts.csv', index_col=0)

# %%
df.head()
# Out:
#             author                                         author_web  shares  \
# 0   Seth Fiegerman         http://mashable.com/people/seth-fiegerman/    4900
# 1     Rebecca Ruiz           http://mashable.com/people/rebecca-ruiz/    1900
# 2  Davina Merchant  http://mashable.com/people/568bdab351984019310...    7000
# 3     Scott Gerber                                                 []    5000
# 4      Josh Dickey             http://mashable.com/people/joshdickey/    1600
#
#                                                 text  \
# 0  \nApple's long and controversial ebook case ha...
# 1  Analysis\n\n\n\n\n\nThere is a reason that Don...
# 2  LONDON - Last month we reported on a dog-sized...
# 3  Today's digital marketing experts must have a ...
# 4  LOS ANGELES — For big, fun, populist popcorn m...
#
#                                                title  \
# 0         The Supreme Court smacked down Apple today
# 1        Every woman has met a man like Donald Trump
# 2  Adorable dog-sized rabbit finally finds his fo...
# 3  15 essential skills all digital marketing hire...
# 4  Mashable top 10: 'The Force Awakens' is the be...
#
#                                facebo  \
# 0  http://www.facebook.com/sfiegerman
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#                                               google  \
# 0                                                NaN
# 1                                                NaN
# 2  https://plus.google.com/105525238342980116477?...
# 3                                                NaN
# 4  https://plus.google.com/109213469090692520544?...
#
#                                   linked                            twitte  \
# 0  http://www.linkedin.com/in/sfiegerman    https://twitter.com/sfiegerman
# 1                                    NaN  https://twitter.com/rebecca_ruiz
# 2                                    NaN                               NaN
# 3                                    NaN                               NaN
# 4                                    NaN       https://twitter.com/JLDlite
#
#    twitter_followers
# 0              14300
# 1               3738
# 2                  0
# 3                  0
# 4              11200

# %% [markdown]
# # Tokenization
#
# - **What:** Separate text into units such as sentences or words
# - **Why:** Gives structure to previously unstructured text
# - **Notes:** Relatively easy with English language text, not easy with some languages

# %% [markdown]
# ### Create the target feature (number of shares)

# %%
y = df.shares
y.describe()
# Out:
# count       82.000000
# mean      3090.487805
# std       8782.031594
# min        437.000000
# 25%        893.500000
# 50%       1200.000000
# 75%       2275.000000
# max      63100.000000
# Name: shares, dtype: float64

# %%
y = pd.cut(y, [0, 893, 1200, 2275, 63200], labels=[0, 1, 2, 3])

# %%
y.value_counts()
# Out:
# 1    22
# 0    21
# 3    21
# 2    18
# Name: shares, dtype: int64

# %%
df['y'] = y

# %% [markdown]
# ### create document-term matrices

# %%
X = df.text
X
# Out:
# 0     \nApple's long and controversial ebook case ha...
# 1     Analysis\n\n\n\n\n\nThere is a reason that Don...
# 2     LONDON - Last month we reported on a dog-sized...
# 3     Today's digital marketing experts must have a ...
# 4     LOS ANGELES — For big, fun, populist popcorn m...
#                             ...
# 77    In recent years, a lot of time has been spent ...
# 78    \n\n\n\nFrom the man whose messed-up brain gav...
# 79    For the last few years, Tesla has been playing...
# 80    This story was updated at 5:55 p.m. ET with mo...
# 81    Every day it seems there's a new way to go to ...
# Name: text, Length: 82, dtype: object

# %%
# use CountVectorizer to create document-term matrices from X
vect = CountVectorizer()
X_dtm = vect.fit_transform(X)

# %%
vect.vocabulary_
# Out:
# {'apple': 682,
#  'long': 4303,
#  'and': 617,
#  'controversial': 1747,
#  'ebook': 2401,
#  'case': 1307,
#  'has': 3367,
#  'reached': 5734,
#  'its': 3884,
#  'final': 2893,
#  'chapter': 1383,
#  'it': 3878,
#  'not': 4883,
#  'the': 7054,
#  'happy': 3352,
#  'ending': 2527,
#  'company': 1612,
#  'wanted': 7620,
#  'supreme': 6865,
#  'court': 1809,
#  'on': 4969,
#  'monday': 4687,
#  'rejected': 5841,
#  'an': 603,
#  'appeal': 673,
#  'filed': 2882,
#  'by': 1224,
#  'to': 7150,
#  'overturn': 5075,
#  'stinging': 6723,
#  'ruling': 6087,
#  'that': 7051,
#  'led': 4181,
#  'broad': 1147,
#  'conspiracy': 1706,
#  'with': 7748,
#  'several': 6303,
#  'major': 4374,
#  'publishers': 5610,
#  'fix': 2927,
#  'price': 5483,
#  'of': 4935,
#  'books': 1088,
#  'sold': 6528,
#  'through': 7106,
#  'online': 4979,
#  'bookstore': 1089,
#  'decision': 2009,
#  'means': 4496,
#  'now': 4895,
#  'no': 4858,
#  'choice': 1437,
#  'but': 1215,
#  'pay': 5178,
#  'out': 5037,
#  '400': 223,
#  'million': 4611,
#  'consumers': 1714,
#  'additional': 446,
#  '50': 252,
#  'in': 3664,
#  'legal': 4187,
#  'fees': 2846,
#  'according': 400,
#  'original': 5021,
#  'settlement': 6301,
#  '2014': 153,
#  'see': 6237,
#  'also': 575,
#  'here': 3440,
#  'how': 3559,
#  'marshalled': 4437,
#  'entire': 2564,
#  'tech': 6989,
#  'industry': 3712,
#  'fight': 2876,
#  'fbi': 2826,
#  'for': 2996,
#  'verdict': 7519,
#  'is': 3863,
#  'more': 4700,
#  'damaging': 1939,
#  'reputation': 5917,
#  'as': 734,
#  'consumer': 1713,
#  'friendly': 3072,
#  'brand': 1120,
#  'mention': 4539,
#  'legacy': 4186,
#  'beloved': 959,
#  'founder': 3036,
#  'steve': 6715,
#  'jobs': 3938,
#  'than': 7045,
#  'actual': 432,
#  'bottom': 1102,
#  'line': 4252,
#  'put': 5636,
#  'fine': 2903,
#  'context': 1727,
#  'total': 7188,
#  '450': 237,
#  'payout': 5183,
#  'equal': 2581,
#  'about': 374,
#  'little': 4276,
#  'half': 3328,
#  'sales': 6118,
#  'generates': 3151,
#  'average': 821,
#  'each': 2382,
#  'day': 1972,
#  'based': 895,
#  '75': 314,
#  'billion': 998,
#  'revenue': 5987,
#  'reported': 5897,
#  'most': 4707,
#  'recent': 5773,
#  'quarter': 5651,
#  'fixing': 2929,
#  'episode': 2579,
#  'dates': 1962,
#  'back': 854,
#  'late': 4130,
#  '2009': 148,
#  'just': 3986,
#  'ahead': 513,
#  'ipad': 3856,
#  'launch': 4141,
#  'recognizing': 5780,
#  'would': 7787,
#  'likely': 4244,
#  'be': 924,
#  'big': 990,
#  'selling': 6253,
#  'point': 5339,
#  'tablet': 6925,
#  'began': 942,
#  'courting': 1812,
#  'what': 7686,
#  'were': 7681,
#  'then': 7065,
#  'five': 2926,
#  'book': 1084,
#  'series': 6283,
#  'mails': 4367,
#  'later': 4132,
#  'released': 5854,
#  'government': 3237,
#  'personally': 5232,
#  'persuaded': 5234,
#  'publishing': 5611,
#  'executives': 2680,
#  're': 5732,
#  'think': 7078,
#  'flat': 2941,
#  '99': 344,
#  'pricing': 5487,
#  'previously': 5481,
#  'imposed': 3652,
#  'amazon': 584,
#  'giant': 3181,
#  'world': 7779,
#  'all': 558,
#  'tell': 7004,
#  'us': 7462,
#  'new': 4830,
#  'releases': 5855,
#  'eroding': 2593,
#  'value': 7496,
#  'perception': 5210,
#  'their': 7058,
#  'products': 5525,
#  'customer': 1911,
#  'minds': 4619,
#  'they': 7072,
#  'do': 2262,
#  'want': 7619,
#  'this': 7082,
#  'practice': 5417,
#  'continue': 1729,
#  'wrote': 7801,
#  'one': 4972,
#  'email': 2473,
#  'james': 3898,
#  'murdoch': 4746,
#  'executive': 2679,
#  'at': 765,
#  'news': 4833,
#  'corp': 1777,
#  'which': 7699,
#  'owns': 5083,
#  'harper': 3362,
#  'collins': 1552,
#  'ceo': 1348,
#  'sent': 6268,
#  'exec': 2675,
#  'image': 3625,
#  'screengrab': 6201,
#  'mashablethe': 4452,
#  'unhappy': 7404,
#  'unfavorable': 7400,
#  'terms': 7024,
#  'agreed': 507,
#  'signed': 6404,
#  'plan': 5303,
#  'used': 7466,
#  'competition': 1621,
#  'pressure': 5469,
#  'into': 3821,
#  'changing': 1375,
#  'own': 5079,
#  'structure': 6774,
#  'while': 7700,
#  'some': 6539,
#  'argued': 707,
#  'move': 4724,
#  'helped': 3432,
#  'break': 1125,
#  'up': 7441,
#  'potential': 5404,
#  'monopoly': 4692,
#  'market': 4427,
#  'accused': 406,
#  'colluding': 1553,
#  'keep': 4015,
#  'prices': 5486,
#  'high': 3461,
#  'hachette': 3318,
#  'harpercollins': 3363,
#  'macmillan': 4355,
#  'penguin': 5200,
#  'simon': 6420,
#  'schuster': 6181,
#  'settled': 6300,
#  'department': 2087,
#  'justice': 3987,
#  'before': 941,
#  'going': 3214,
#  'trial': 7274,
#  'only': 4980,
#  'armed': 713,
#  'unwavering': 7438,
#  'belief': 953,
#  'rightness': 6014,
#  'courts': 1814,
#  'we': 7653,
#  'are': 700,
#  'ready': 5747,
#  'distribute': 2249,
#  'mandated': 4396,
#  'funds': 3097,
#  'kindle': 4046,
#  'customers': 1912,
#  'soon': 6551,
#  'instructed': 3783,
#  'forward': 3029,
#  'spokesperson': 6623,
#  'said': 6111,
#  'statement': 6686,
#  'provided': 5585,
#  'mashable': 4448,
#  'reps': 5913,
#  'did': 2160,
#  'immediately': 3637,
#  'respond': 5948,
#  'our': 5036,
#  'request': 5918,
#  'comment': 1584,
#  'however': 3560,
#  'after': 490,
#  'loss': 4319,
#  '2013': 152,
#  'says': 6158,
#  'when': 7694,
#  'introduced': 3825,
#  'ibookstore': 3599,
#  '2010': 149,
#  'gave': 3138,
#  'injecting': 3745,
#  'much': 4740,
#  'needed': 4808,
#  'innovation': 3753,
#  'breaking': 1126,
#  'monopolistic': 4691,
#  'grip': 3280,
#  'time': 7129,
#  've': 7511,
#  'done': 2293,
#  'nothing': 4887,
#  'wrong': 7799,
#  'have': 3380,
#  'once': 4971,
#  'again': 493,
#  'determined': 2135,
#  'otherwise': 5033,
#  'analysis': 608,
#  'there': 7069,
#  'reason': 5760,
#  'donald': 2289,
#  'trump': 7296,
#  'outrageous': 5052,
#  'statements': 6687,
#  'behavior': 948,
#  'feel': 2842,
#  'familiar': 2789,
#  'many': 4410,
#  'women': 7757,
#  'because': 933,
#  'know': 4065,
#  'his': 3484,
#  'declarative': 2014,
#  'style': 6796,
#  'trademark': 7221,
#  'shrug': 6390,
#  'from': 3077,
#  'reality': 5751,
#  'television': 7002,
#  'or': 5005,
#  'political': 5350,
#  'debates': 1995,
#  'nor': 4873,
#  'outsized': 5055,
#  'role': 6051,
#  'american': 590,
#  'business': 1211,
#  'made': 4357,
#  'unforgettable': 7402,
#  'impression': 3655,
#  'them': 7061,
#  'targets': 6961,
#  'republicans': 5916,
#  'say': 6156,
#  'he': 3389,
#  'could': 1792,
#  'cost': 1786,
#  'party': 5150,
#  'everything': 2643,
#  'eerie': 2424,
#  'familiarity': 2790,
#  'personal': 5230,
#  'encountered': 2522,
#  'man': 4388,
#  'like': 4242,
#  'him': 3473,
#  'home': 3507,
#  'work': 7768,
#  'social': 6518,
#  'media': 4505,
#  'relationship': 5848,
#  'extols': 2739,
#  'virtues': 7563,
#  'problem': 5508,
#  'reducing': 5799,
#  'sex': 6305,
#  'objects': 4915,
#  'casts': 1314,
#  'himself': 3474,
#  'unflappable': 7401,
#  'blames': 1030,
#  'woman': 7756,
#  'weaknesses': 7655,
#  'revealed': 5982,
#  'insists': 3767,
#  'responsibility': 5954,
#  'denies': 2078,
#  'deflects': 2046,
#  'perhaps': 5221,
#  'even': 2627,
#  'turns': 7322,
#  'violent': 7557,
#  'wrongdoing': 7800,
#  'so': 6513,
#  'me': 4489,
#  'wow': 7791,
#  'tough': 7195,
#  'nobody': 4860,
#  'respect': 5946,
#  'realdonaldtrump': 5750,
#  'march': 4417,
#  '26': 180,
#  '2016': 155,
#  'psychological': 5595,
#  'warfare': 7623,
#  'gaslighting': 3134,
#  'subtle': 6807,
#  'form': 3013,
#  'emotional': 2504,
#  'abuse': 382,
#  'puts': 5637,
#  'victim': 7536,
#  'defensive': 2039,
#  'go': 3206,
#  'strategy': 6752,
#  'sees': 6246,
#  'actions': 422,
#  'arguably': 706,
#  'projects': 5540,
#  'voters': 7597,
#  'tuesday': 7305,
#  'florida': 2962,
#  'police': 5346,
#  'charged': 1387,
#  'campaign': 1250,
#  'manager': 4392,
#  'corey': 1775,
#  'lewandowski': 4213,
#  'battery': 908,
#  'female': 2853,
#  'reporter': 5899,
#  'issued': 3876,
#  'tweets': 7333,
#  'refuting': 5817,
#  'video': 7542,
#  'evidence': 2648,
#  'discrediting': 2221,
#  'journalist': 3960,
#  'implying': 3648,
#  'she': 6332,
#  'been': 939,
#  'dangerous': 1945,
#  'deadly': 1984,
#  'threat': 7094,
#  'my': 4760,
#  'very': 7527,
#  'decent': 2005,
#  'was': 7632,
#  'assaulting': 749,
#  'look': 4306,
#  'tapes': 6956,
#  '29': 189,
#  'powerful': 5415,
#  'left': 4185,
#  'right': 6013,
#  'forcefully': 3000,
#  'criticized': 1863,
#  'reaction': 5740,
#  'charges': 1389,
#  'too': 7172,
#  'often': 4952,
#  'victims': 7538,
#  'violence': 7556,
#  'stay': 6694,
#  'silent': 6411,
#  'remarks': 5870,
#  'today': 7152,
#  'demonstrate': 2072,
#  'reasons': 5762,
#  'why': 7709,
#  'dawn': 1970,
#  'laguens': 4104,
#  'vice': 7533,
#  'president': 5458,
#  'planned': 5305,
#  'parenthood': 5130,
#  'action': 420,
#  'fund': 3094,
#  'underscore': 7386,
#  'fiction': 2867,
#  'supportive': 6862,
#  'any': 659,
#  'country': 1802,
#  'reporters': 5900,
#  'found': 3033,
#  'tape': 6954,
#  'facility': 2765,
#  'changed': 1373,
#  'her': 3439,
#  'tune': 7308,
#  'pic': 5265,
#  'twitter': 7336,
#  'com': 1560,
#  'n5815rs1at': 4764,
#  'touching': 7194,
#  'leave': 4176,
#  'conference': 1664,
#  'hand': 3336,
#  'hqb8dl0fhn': 3562,
#  'wednesday': 7664,
#  'group': 3283,
#  'conservative': 1695,
#  'journalists': 3961,
#  'commentators': 1588,
#  'called': 1238,
#  'firing': 2916,
#  'track': 7216,
#  'record': 5783,
#  'making': 4381,
#  'defenders': 2036,
#  'seem': 6241,
#  'foolish': 2991,
#  'ones': 4974,
#  'nichole': 4845,
#  'bauer': 914,
#  'assistant': 755,
#  'professor': 5529,
#  'science': 6183,
#  'university': 7414,
#  'alabama': 541,
#  'response': 5951,
#  'classic': 1482,
#  'practiced': 5418,
#  'denying': 2084,
#  'previous': 5480,
#  'incontrovertible': 3684,
#  'exists': 2686,
#  'isn': 3871,
#  'exclusive': 2673,
#  'commentary': 1586,
#  'course': 1808,
#  'wasn': 7637,
#  'reference': 5803,
#  'menstruation': 4535,
#  'joked': 3950,
#  'fox': 3040,
#  'anchor': 614,
#  'megyn': 4522,
#  'kelly': 4019,
#  'having': 3382,
#  'blood': 1050,
#  'coming': 1579,
#  'wherever': 7697,
#  'during': 2363,
#  'debate': 1994,
#  'certainly': 1351,
#  'use': 7465,
#  'schlonged': 6177,
#  'vulgar': 7603,
#  'term': 7022,
#  'describing': 2104,
#  'badly': 865,
#  'pres': 5450,
#  'barack': 885,
#  'obama': 4909,
#  'beat': 928,
#  'hillary': 3470,
#  'clinton': 1503,
#  '2008': 147,
#  'democratic': 2069,
#  'presidential': 5459,
#  'primary': 5489,
#  'press': 5461,
#  'way': 7650,
#  'convince': 1755,
#  'people': 5205,
#  'opposite': 5000,
#  'definitely': 2042,
#  'accepted': 388,
#  'among': 596,
#  'republican': 5915,
#  'mainstream': 4369,
#  'sort': 6556,
#  'outmoded': 5050,
#  'sexism': 6306,
#  'demonstrates': 2074,
#  'real': 5749,
#  'place': 5298,
#  'discourse': 2218,
#  'yet': 7832,
#  'instead': 3779,
#  'apologizing': 669,
#  'acknowledging': 413,
#  'question': 5660,
#  'matter': 4469,
#  'might': 4590,
#  'find': 2899,
#  'offensive': 4939,
#  'doubled': 2305,
#  'down': 2308,
#  'obfuscated': 4910,
#  'whether': 7698,
#  'coworker': 1821,
#  'who': 7703,
#  'meaning': 4493,
#  'sexist': 6307,
#  'partner': 5144,
#  'quick': 5664,
#  'end': 2525,
#  'argument': 709,
#  'using': 7471,
#  'word': 7765,
#  'telling': 7005,
#  'don': 2287,
#  'deserve': 2106,
#  'same': 6123,
#  'agency': 498,
#  'men': 4533,
#  'denials': 2076,
#  'may': 4477,
#  'make': 4376,
#  'appear': 674,
#  'unassailable': 7366,
#  'send': 6260,
#  'entirely': 2565,
#  'different': 2171,
#  'message': 4551,
#  'nature': 4788,
#  'tend': 7014,
#  'support': 6858,
#  'traditional': 7226,
#  'roles': 6052,
#  'believing': 957,
#  'deference': 2040,
#  'male': 4383,
#  'authority': 807,
#  'figure': 2879,
#  'husband': 3594,
#  'faultless': 2817,
#  'effectively': 2430,
#  'takes': 6941,
#  'autonomy': 815,
#  'away': 833,
#  'creating': 1840,
#  'climate': 1498,
#  'always': 580,
#  'explain': 2708,
#  'performed': 5217,
#  'poorly': 5363,
#  'survey': 6879,
#  'nbc': 4795,
#  'wsj': 7802,
#  'poll': 5354,
#  '47': 242,
#  'cannot': 1267,
#  'themselves': 7064,
#  'voting': 7599,
#  'favorability': 2820,
#  'ratings': 5726,
#  'higher': 3462,
#  '59': 282,
#  'amongst': 597,
#  'registered': 5823,
#  'cnn': 1520,
#  'orc': 5006,
#  'though': 7087,
#  'ask': 739,
#  'intended': 3795,
#  'vote': 7594,
#  'don_vito_08': 2288,
#  'picture': 5274,
#  'worth': 7786,
#  'thousand': 7091,
#  'words': 7767,
#  'lyingted': 4347,
#  'nevercruz': 4828,
#  'melaniatrump': 4524,
#  '5bvvewmvf8': 285,
#  '24': 174,
#  'these': 7071,
#  'polls': 5356,
#  'fully': 3089,
#  'reflect': 5808,
#  'unseemly': 7429,
#  'attacks': 776,
#  'heidi': 3423,
#  'cruz': 1883,
#  'wife': 7718,
#  'opponent': 4995,
#  'sen': 6258,
#  'ted': 6997,
#  'if': 3613,
#  'abortion': 373,
#  'banned': 881,
#  'illegally': 3620,
#  'should': 6371,
#  'face': 2758,
#  'punishment': 5623,
#  'clarified': 1478,
#  'hypothetical': 3598,
#  'reversed': 5989,
#  'position': 5385,
#  'clear': 1488,
#  'willing': 7724,
#  'publicly': 5605,
#  'embarrass': 2478,
#  'degrade': 2050,
#  'consider': 1696,
#  'depriving': 2096,
#  'physical': 5263,
#  'freedom': 3054,
#  'such': 6814,
#  'power': 5413,
#  'dynamics': 2372,
#  'aren': 703,
#  'abusive': 383,
#  'workplaces': 7776,
#  'relationships': 5849,
#  'fathom': 2815,
#  'mirrors': 4637,
#  'private': 5500,
#  'hell': 3428,
#  'doing': 2280,
#  'control': 1744,
#  'others': 5032,
#  'elevate': 2454,
#  'insulate': 3785,
#  'attack': 772,
#  'jackie': 3890,
#  'white': 7702,
#  'emerita': 2491,
#  'psychology': 5597,
#  'senior': 6262,
#  'research': 5925,
#  'scientist': 6186,
#  'center': 1342,
#  'health': 3401,
#  'wellness': 7678,
#  'north': 4878,
#  'carolina': 1291,
#  'greensboro': 3269,
#  'approach': 690,
#  'victimizes': 7537,
#  'playing': 5323,
#  'part': 5138,
#  'degradation': 2049,
#  'manipulation': 4401,
#  'present': 5453,
#  'self': 6251,
#  'assured': 763,
#  'knowledgable': 4067,
#  'person': 5228,
#  'meanwhile': 4498,
#  'silences': 6410,
#  'depressed': 2094,
#  'passive': 5161,
#  'paralyzed': 5127,
#  'feelings': 2844,
#  'doubt': 2307,
#  'insecurity': 3758,
#  'set': 6295,
#  'experience': 2701,
#  'well': 7677,
#  'worries': 7782,
#  'tactics': 6931,
#  'display': 2236,
#  'consciously': 1690,
#  'subconsciously': 6800,
#  'lead': 4155,
#  'endorse': 2530,
#  'harmful': 3361,
#  'stereotypes': 6714,
#  'engage': 2539,
#  'particularly': 5141,
#  'threatened': 7095,
#  'demographic': 2071,
#  'change': 1372,
#  'evolving': 2652,
#  'gender': 3147,
#  'inspire': 3771,
#  'justified': 3989,
#  'clinging': 1501,
#  'deserved': 2107,
#  'elevated': 2455,
#  'status': 6693,
#  'makes': 4380,
#  'offering': 4942,
#  'public': 5604,
#  'performance': 5215,
#  'fallout': 2785,
#  'unconscionable': 7374,
#  'both': 1101,
#  'london': 4302,
#  'last': 4127,
#  'month': 4695,
#  'dog': 2276,
#  'sized': 6444,
#  'rabbit': 5678,
#  'desperate': 2117,
#  'need': 4807,
#  'under': 7379,
#  'atlas': 770,
#  'permanent': 5223,
#  'story': 6739,
#  'went': 7680,
#  'global': 3199,
#  'over': 5061,
#  'including': 3678,
#  'canada': 1255,
#  'france': 3043,
#  'started': 6679,
#  'reaching': 5736,
#  'scottish': 6195,
#  'society': 6520,
#  'prevention': 5477,
#  'cruelty': 1879,
#  'animals': 633,
#  'thanks': 7049,
#  'jen': 3920,
#  'hislop': 3485,
#  'ayrshire': 839,
#  'adorable': 459,
#  'bunny': 1196,
#  'will': 7721,
#  'get': 3173,
#  'native': 4785,
#  'scotland': 6193,
#  'buggy': 1178,
#  'facebook': 2759,
#  'spcajen': 6581,
#  'financial': 2898,
#  'fraud': 3049,
#  'investigator': 3836,
#  'told': 7157,
#  'charity': 1391,
#  'burst': 1205,
#  'tears': 6985,
#  'got': 3230,
#  'phone': 5251,
#  'call': 1237,
#  'saying': 6157,
#  'had': 3322,
#  'chosen': 1448,
#  'cried': 1854,
#  'collected': 1547,
#  '43': 231,
#  'year': 7822,
#  'old': 4962,
#  'two': 7339,
#  'bunnies': 1195,
#  'currently': 1906,
#  'rex': 5997,
#  'named': 4772,
#  'coconut': 1528,
#  'looking': 4309,
#  'still': 6722,
#  'growing': 3287,
#  'summer': 6839,
#  'house': 3552,
#  'heating': 3414,
#  'air': 525,
#  'conditioning': 1659,
#  'accommodation': 396,
#  'large': 4122,
#  'garden': 3128,
#  'enclosure': 2519,
#  'run': 6089,
#  'perfect': 5211,
#  'addition': 445,
#  'family': 2792,
#  'thing': 7076,
#  'name': 4771,
#  'hello': 3430,
#  'atilla': 767,
#  'bun': 1193,
#  'binky': 1003,
#  'master': 4458,
#  'jazz': 3913,
#  'paws': 5177,
#  'worry': 7783,
#  'you': 7836,
#  'can': 1254,
#  'atty': 789,
#  'short': 6360,
#  'digital': 2179,
#  'marketing': 4430,
#  'experts': 2707,
#  'must': 4754,
#  'diverse': 2254,
#  'skill': 6447,
#  'sophisticated': 6553,
#  'grasp': 3257,
#  'available': 816,
#  'channels': 1378,
#  'ability': 370,
#  'identify': 3608,
#  'opportunities': 4997,
#  'top': 7177,
#  'basic': 897,
#  'skills': 6448,
#  'brilliant': 1140,
#  'marketer': 4428,
#  'possess': 5389,
#  'balance': 871,
#  'critical': 1860,
#  'creative': 1843,
#  'thinking': 7079,
#  'order': 5008,
#  'drive': 2336,
#  'measurable': 4499,
#  'success': 6811,
#  'asked': 740,
#  '15': 72,
#  'members': 4528,
#  'young': 7837,
#  'entrepreneur': 2570,
#  'council': 1794,
#  'yec': 7824,
#  'hiring': 3483,
#  'marketers': 4429,
#  'best': 974,
#  'answers': 653,
#  'below': 960,
#  'paid': 5106,
#  'advertising': 471,
#  'expertise': 2706,
#  'hire': 3480,
#  'versed': 7523,
#  'especially': 2595,
#  'similar': 6419,
#  'platform': 5312,
#  'uses': 7470,
#  'regularly': 5826,
#  'able': 371,
#  'understand': 7387,
#  'implement': 3647,
#  'analytics': 611,
#  'insights': 3764,
#  'create': 1837,
#  'lookalike': 4307,
#  'custom': 1910,
#  'audiences': 793,
#  'experiment': 2704,
#  'test': 7033,
#  'images': 3627,
#  'secure': 6234,
#  'knowledge': 4068,
#  'overall': 5062,
#  'landscape': 4112,
#  'budget': 1173,
#  'saving': 6153,
#  'within': 7750,
#  'space': 6576,
#  'sure': 6866,
#  'talent': 6943,
#  'knows': 4070,
#  'ins': 3757,
#  'outs': 5053,
#  'popular': 5369,
#  'easy': 2398,
#  'miles': 4599,
#  'jennings': 3922,
#  'recruiter': 5790,
#  'web': 7661,
#  'developers': 2142,
#  'data': 1959,
#  'scientists': 6187,
#  'ai': 514,
#  'hired': 3481,
#  'years': 7823,
#  'outsourced': 5056,
#  'successfully': 6813,
#  'better': 979,
#  'turn': 7317,
#  'your': 7840,
#  'closing': 1511,
#  'deals': 1989,
#  'directly': 2198,
#  'sell': 6252,
#  'll': 4281,
#  'wasting': 7640,
#  'valuable': 7495,
#  'dollars': 2282,
#  'without': 7751,
#  'generating': 3152,
#  'qualified': 5646,
#  'team': 6982,
#  'mark': 4425,
#  'cenicola': 1341,
#  'bannerview': 882,
#  'specific': 6594,
#  'channel': 1376,
#  'extol': 2738,
#  'every': 2639,
#  'conceivable': 1646,
#  'seo': 6270,
#  'sem': 6254,
#  'etc': 2609,
#  'key': 4026,
#  'successful': 6812,
#  'focusing': 2977,
#  'few': 2861,
#  'really': 5756,
#  'understanding': 7388,
#  'deeply': 2027,
#  'leveraging': 4211,
#  'those': 7086,
#  'example': 2659,
#  'helping': 3434,
#  'local': 4288,
#  'businesses': 1212,
#  'pinterest': 5282,
#  'less': 4200,
#  'interesting': 3806,
#  'although': 578,
#  'drivers': 2338,
#  'ecommerce': 2403,
#  'traffic': 7230,
#  'rather': 5723,
#  'focus': 2975,
#  'intricate': 3823,
#  'client': 1495,
#  'google': 3225,
#  'maps': 4416,
#  'yelp': 7827,
#  'trevor': 7273,
#  'sumner': 6841,
#  'localvox': 4291,
#  'objectively': 4914,
#  'usually': 7475,
#  ...}

# %%
len(vect.vocabulary_)
# Out:
# 7710

# %%
# rows are documents, columns are terms (aka "tokens" or "features")
X_dtm.shape
# Out:
# (82, 7969)

# %%
# last 50 features
print(vect.get_feature_names()[-150:-100])
# Out:
# ['y9mqjvndab', 'yancy', 'yang', 'yd5ksw4vsr', 'ydwnm50jlu', 'ye', 'yeah', 'year', 'years', 'yec', 'yeezy', 'yellow', 'yelp', 'yep', 'yes', 'yesterday', 'yesweather', 'yoga', 'yong', 'york', 'young', 'younger', 'youngest', 'youth', 'youtube', 'youtubeduck', 'yup', 'yuyuan', 'yücel', 'zach', 'zaxoqbv487', 'zero', 'zgkymde1lzewlza0l2zkl1n0yxj0dxayljq0mdvhlmpwzwpwcxrodw1ictexnxgxmtujcmujanbn', 'zgkymde1lzewlza0l2zkl1n0yxj0dxayljq0mdvhlmpwzwpwcxrodw1icteymdb4nji3iwplcwpwzw', 'zgkymde1lzewlza0l2zkl1n0yxj0dxayljq0mdvhlmpwzwpwcxrodw1icti4ohgxnjijcmujanbn', 'zgkymde1lzewlza0l2zkl1n0yxj0dxayljq0mdvhlmpwzwpwcxrodw1ictk1mhg1mzqjcmujanbn', 'zgkymde1lzewlza0l2zkl1n0yxj0dxayljq0mdvhlmpwzwpwcxrodw1ictu2mhg3ntakzqlqcgc', 'zgkymde1lzewlza0l2zkl1n0yxj0dxayljq0mdvhlmpwzwpwcxrodw1ictywmhgzmzgjcmujanbn', 'zgkymde1lzewlza0lzm1l2jpcmrfdgfudhj1lmu3zwmzlmpwzwpwcxrodw1ictexnxgxmtujcmujanbn', 'zgkymde1lzewlza0lzm1l2jpcmrfdgfudhj1lmu3zwmzlmpwzwpwcxrodw1icteymdb4nji3iwplcwpwzw', 'zgkymde1lzewlza0lzm1l2jpcmrfdgfudhj1lmu3zwmzlmpwzwpwcxrodw1icti4ohgxnjijcmujanbn', 'zgkymde1lzewlza0lzm1l2jpcmrfdgfudhj1lmu3zwmzlmpwzwpwcxrodw1ictk1mhg1mzqjcmujanbn', 'zgkymde1lzewlza0lzm1l2jpcmrfdgfudhj1lmu3zwmzlmpwzwpwcxrodw1ictu2mhg3ntakzqlqcgc', 'zgkymde1lzewlza0lzm1l2jpcmrfdgfudhj1lmu3zwmzlmpwzwpwcxrodw1ictywmhgzmzgjcmujanbn', 'zgkymde1lzewlzaxlzhhl1rttfnjcmvlblnolmnkmgjklnbuzwpwcxrodw1ictexnxgxmtujcmujanbn', 'zgkymde1lzewlzaxlzhhl1rttfnjcmvlblnolmnkmgjklnbuzwpwcxrodw1icteymdb4nji3iwplcwpwzw', 'zgkymde1lzewlzaxlzhhl1rttfnjcmvlblnolmnkmgjklnbuzwpwcxrodw1icti4ohgxnjijcmujanbn', 'zgkymde1lzewlzaxlzhhl1rttfnjcmvlblnolmnkmgjklnbuzwpwcxrodw1ictk1mhg1mzqjcmujanbn', 'zgkymde1lzewlzaxlzhhl1rttfnjcmvlblnolmnkmgjklnbuzwpwcxrodw1ictu2mhg3ntakzqlqcgc', 'zgkymde1lzewlzaxlzhhl1rttfnjcmvlblnolmnkmgjklnbuzwpwcxrodw1ictywmhgzmzgjcmujanbn']

# %%
# show vectorizer options
vect
# Out:
# CountVectorizer()

# %% [markdown]
# - **lowercase:** boolean, True by default
# - Convert all characters to lowercase before tokenizing.

# %%
vect = CountVectorizer(lowercase=False)
X_dtm = vect.fit_transform(X)
X_dtm.shape
# Out:
# (82, 8759)

# %%
vect.get_feature_names()[100]
# Out:
# '1950s'

# %% [markdown]
# - **ngram_range:** tuple (min_n, max_n)
# - The lower and upper boundary of the range of n-values for different n-grams to be extracted. All values of n such that min_n <= n <= max_n will be used.

# %%
# include 1-grams and 2-grams
vect = CountVectorizer(ngram_range=(1, 4))
X_dtm = vect.fit_transform(X)
X_dtm.shape
# Out:
# (82, 115172)

# %%
vect.get_feature_names()[8097:9100]
# Out:
# ['and formidable',
#  'and formidable opponent',
#  'and formidable opponent and',
#  'and forth',
#  'and forth dialogue',
#  'and forth dialogue lapses',
#  'and forth to',
#  'and forth to the',
#  'and founder',
#  'and founder of',
#  'and founder of young',
#  'and france',
#  'and france started',
#  'and france started reaching',
#  'and frequently',
#  'and frequently talked',
#  'and frequently talked about',
#  'and frobscottle',
#  'and frobscottle there',
#  'and frobscottle there finally',
#  'and from',
#  'and from there',
#  'and from there expanded',
#  'and from which',
#  'and from which it',
#  'and full',
#  'and full of',
#  'and full of vigour',
#  'and fun',
#  'and fun activities',
#  'and fun activities to',
#  'and fun lawyer',
#  'and fun lawyer who',
#  'and functionality',
#  'and functionality because',
#  'and functionality because wordpress',
#  'and functions',
#  'and functions much',
#  'and functions much like',
#  'and gail',
#  'and gail and',
#  'and gail and will',
#  'and galaxy',
#  'and galaxy note',
#  'and galaxy note he',
#  'and galifianakis',
#  'and galifianakis as',
#  'and galifianakis as the',
#  'and games',
#  'and games until',
#  'and games until ferrell',
#  'and generally',
#  'and generally lacked',
#  'and generally lacked self',
#  'and gerald',
#  'and gerald ford',
#  'and gerald ford at',
#  'and germany',
#  'and germany continues',
#  'and germany continues to',
#  'and germany where',
#  'and germany where they',
#  'and get',
#  'and get slurpees',
#  'and get slurpees and',
#  'and get to',
#  'and get to ordering',
#  'and gets',
#  'and gets dirty',
#  'and gets dirty can',
#  'and give',
#  'and give bunch',
#  'and give bunch of',
#  'and give mash',
#  'and give mash up',
#  'and give the',
#  'and give the sweet',
#  'and global',
#  'and global leaderboard',
#  'and global leaderboard as',
#  'and globally',
#  'and globally distributed',
#  'and globally distributed the',
#  'and go',
#  'and go to',
#  'and go to cuba',
#  'and goals',
#  'and goals moving',
#  'and goals moving forward',
#  'and goods',
#  'and goods made',
#  'and goods made themselves',
#  'and government',
#  'and government agencies',
#  'and government agencies have',
#  'and grapple',
#  'and grapple away',
#  'and grapple away as',
#  'and grappling',
#  'and grappling and',
#  'and grappling and parachuting',
#  'and gravy',
#  'and gravy as',
#  'and gravy as the',
#  'and greece',
#  'and greece ostojić',
#  'and greece ostojić said',
#  'and grey',
#  'and grey anatomy',
#  'and grey anatomy but',
#  'and guess',
#  'and guess wants',
#  'and guess wants to',
#  'and guests',
#  'and guests coming',
#  'and guests coming even',
#  'and guided',
#  'and guided meditations',
#  'and guided meditations apps',
#  'and guidelines',
#  'and guidelines vary',
#  'and guidelines vary widely',
#  'and hacking',
#  'and hacking team',
#  'and hacking team if',
#  'and had',
#  'and had medical',
#  'and had medical ailments',
#  'and half',
#  'and half below',
#  'and half below the',
#  'and half the',
#  'and half the world',
#  'and handling',
#  'and handling mobility',
#  'and handling mobility aids',
#  'and hard',
#  'and hard to',
#  'and hard to predict',
#  'and hardcopy',
#  'and hardcopy ads',
#  'and hardcopy ads in',
#  'and has',
#  'and has been',
#  'and has been impressing',
#  'and has been shot',
#  'and has even',
#  'and has even been',
#  'and has even blogged',
#  'and has introduced',
#  'and has introduced visual',
#  'and has to',
#  'and has to ask',
#  'and have',
#  'and have determined',
#  'and have determined that',
#  'and have kids',
#  'and have kids decorate',
#  'and have no',
#  'and have no desire',
#  'and have said',
#  'and have said they',
#  'and have them',
#  'and have them try',
#  'and have to',
#  'and have to tell',
#  'and having',
#  'and having her',
#  'and having her juggle',
#  'and hayne',
#  'and hayne was',
#  'and hayne was left',
#  'and he',
#  'and he obviously',
#  'and he obviously takes',
#  'and heading',
#  'and heading up',
#  'and heading up youth',
#  'and heard',
#  'and heard the',
#  'and heard the screams',
#  'and hefty',
#  'and hefty paycheck',
#  'and hefty paycheck from',
#  'and here',
#  'and here are',
#  'and here are the',
#  'and higher',
#  'and higher resolution',
#  'and higher resolution screens',
#  'and hillary',
#  'and hillary won',
#  'and hillary won the',
#  'and hilton',
#  'and hilton in',
#  'and hilton in eliminating',
#  'and hinky',
#  'and hinky edits',
#  'and hinky edits didn',
#  'and his',
#  'and his day',
#  'and his day to',
#  'and his k9',
#  'and his k9 partner',
#  'and his political',
#  'and his political opponents',
#  'and his supporters',
#  'and his supporters aren',
#  'and hits',
#  'and hits on',
#  'and hits on cary',
#  'and hoards',
#  'and hoards of',
#  'and hoards of teen',
#  'and honey',
#  'and honey potato',
#  'and honey potato sticks',
#  'and honor',
#  'and honor our',
#  'and honor our beloved',
#  'and hoped',
#  'and hoped my',
#  'and hoped my colleagues',
#  'and hopeless',
#  'and hopeless not',
#  'and hopeless not nearly',
#  'and hot',
#  'and hot miso',
#  'and hot miso soup',
#  'and houses',
#  'and houses hotel',
#  'and houses hotel dwellers',
#  'and how',
#  'and how daniel',
#  'and how daniel love',
#  'and hungary',
#  'and hungary yet',
#  'and hungary yet slovenia',
#  'and images',
#  'and images and',
#  'and images and be',
#  'and immediate',
#  'and immediate action',
#  'and immediate action while',
#  'and implausibly',
#  'and implausibly quickly',
#  'and implausibly quickly find',
#  'and implement',
#  'and implement facebook',
#  'and implement facebook analytics',
#  'and implying',
#  'and implying she',
#  'and implying she could',
#  'and in',
#  'and in house',
#  'and in house what',
#  'and in paris',
#  'and in paris according',
#  'and in perfect',
#  'and in perfect world',
#  'and in the',
#  'and in the mood',
#  'and india',
#  'and india directed',
#  'and india directed by',
#  'and inexpensive',
#  'and inexpensive customers',
#  'and inexpensive customers pop',
#  'and infantata',
#  'and infantata comes',
#  'and infantata comes your',
#  'and infertility',
#  'and infertility are',
#  'and infertility are extremely',
#  'and influencers',
#  'and influencers someone',
#  'and influencers someone with',
#  'and influential',
#  'and influential audience',
#  'and influential audience around',
#  'and initiative',
#  'and initiative which',
#  'and initiative which help',
#  'and initiatives',
#  'and initiatives marketer',
#  'and initiatives marketer who',
#  'and innovation',
#  'and innovation is',
#  'and innovation is still',
#  'and insecurity',
#  'and insecurity set',
#  'and insecurity set in',
#  'and insights',
#  'and insights create',
#  'and insights create lookalike',
#  'and insisting',
#  'and insisting that',
#  'and insisting that everybody',
#  'and inspected',
#  'and inspected by',
#  'and inspected by state',
#  'and institutions',
#  'and institutions don',
#  'and institutions don even',
#  'and insulate',
#  'and insulate themselves',
#  'and insulate themselves from',
#  'and intel',
#  'and intel to',
#  'and intel to revive',
#  'and intend',
#  'and intend to',
#  'and intend to keep',
#  'and internet',
#  'and internet connections',
#  'and internet connections offer',
#  'and into',
#  'and into the',
#  'and into the plane',
#  'and invest',
#  'and invest in',
#  'and invest in its',
#  'and investors',
#  'and investors so',
#  'and investors so it',
#  'and invites',
#  'and invites them',
#  'and invites them out',
#  'and iraq',
#  'and iraq planning',
#  'and iraq planning to',
#  'and is',
#  'and is having',
#  'and is having hard',
#  'and is surreptitiously',
#  'and is surreptitiously apologizing',
#  'and is the',
#  'and is the first',
#  'and is this',
#  'and is this necessary',
#  'and isn',
#  'and isn scared',
#  'and isn scared to',
#  'and it',
#  'and it betrays',
#  'and it betrays who',
#  'and it criminal',
#  'and it criminal that',
#  'and it did',
#  'and it did so',
#  'and it fucks',
#  'and it fucks up',
#  'and it girl',
#  'and it girl gigi',
#  'and it is',
#  'and it is now',
#  'and it isn',
#  'and it isn just',
#  'and it lucca',
#  'and it lucca surprisingly',
#  'and it never',
#  'and it never been',
#  'and it not',
#  'and it not the',
#  'and it one',
#  'and it one without',
#  'and it seems',
#  'and it seems like',
#  'and it seriously',
#  'and it seriously throwing',
#  'and it unclear',
#  'and it unclear when',
#  'and it very',
#  'and it very special',
#  'and it wasn',
#  'and it wasn yet',
#  'and it will',
#  'and it will be',
#  'and its',
#  'and its founder',
#  'and its founder recognizing',
#  'and its hot',
#  'and its hot dog',
#  'and its quarterly',
#  'and its quarterly mobile',
#  'and its rivals',
#  'and its rivals want',
#  'and its role',
#  'and its role there',
#  'and january',
#  'and january travel',
#  'and january travel dates',
#  'and jennifer',
#  'and jennifer the',
#  'and jennifer the subject',
#  'and joining',
#  'and joining alicia',
#  'and joining alicia again',
#  'and journalists',
#  'and journalists at',
#  'and journalists at beijing',
#  'and juice',
#  'and juice from',
#  'and juice from the',
#  'and jumping',
#  'and jumping and',
#  'and jumping and grappling',
#  'and just',
#  'and just go',
#  'and just go ham',
#  'and just want',
#  'and just want to',
#  'and kalinda',
#  'and kalinda departing',
#  'and kalinda departing cary',
#  'and kalinda left',
#  'and kalinda left the',
#  'and kanalturk',
#  'and kanalturk were',
#  'and kanalturk were able',
#  'and kinross',
#  'and kinross council',
#  'and kinross council as',
#  'and kinross council confirmed',
#  'and korean',
#  'and korean weeks',
#  'and korean weeks before',
#  'and land',
#  'and land at',
#  'and land at the',
#  'and laptop',
#  'and laptop computers',
#  'and laptop computers even',
#  'and later',
#  'and later aes',
#  'and later aes 256',
#  'and later used',
#  'and later used the',
#  'and latest',
#  'and latest features',
#  'and latest features the',
#  'and latino',
#  'and latino superheroes',
#  'and latino superheroes immediately',
#  'and legal',
#  'and legal challenges',
#  'and legal challenges the',
#  'and legends',
#  'and legends like',
#  'and legends like roger',
#  'and lenovo',
#  'and lenovo are',
#  'and lenovo are joining',
#  'and leslie',
#  'and leslie jones',
#  'and leslie jones face',
#  'and let',
#  'and let him',
#  'and let him down',
#  'and let the',
#  'and let the kids',
#  'and leveraging',
#  'and leveraging brands',
#  'and leveraging brands then',
#  'and leveraging those',
#  'and leveraging those dynamics',
#  'and light',
#  'and light gaming',
#  'and light gaming which',
#  'and light musings',
#  'and light musings suddenly',
#  'and likable',
#  'and likable personality',
#  'and likable personality can',
#  'and lionsgate',
#  'and lionsgate first',
#  'and lionsgate first announced',
#  'and long',
#  'and long term',
#  'and long term goals',
#  'and look',
#  'and look towards',
#  'and look towards me',
#  'and looked',
#  'and looked stupid',
#  'and looked stupid to',
#  'and lose',
#  'and lose ground',
#  'and lose ground fast',
#  'and lost',
#  'and lost at',
#  'and lost at lockhart',
#  'and lucasfilm',
#  'and lucasfilm basically',
#  'and lucasfilm basically recreated',
#  'and lucca',
#  'and lucca sharing',
#  'and lucca sharing drink',
#  'and macedonia',
#  'and macedonia and',
#  'and macedonia and greece',
#  'and maintain',
#  'and maintain my',
#  'and maintain my integrity',
#  'and making',
#  'and making them',
#  'and making them even',
#  'and manage',
#  'and manage blog',
#  'and manage blog or',
#  'and mangled',
#  'and mangled self',
#  'and mangled self esteem',
#  'and many',
#  'and many are',
#  'and many are concerned',
#  'and many channels',
#  'and many channels might',
#  'and many don',
#  'and many don know',
#  'and many more',
#  'and many more refugees',
#  'and many more the',
#  'and many other',
#  'and many other p2p',
#  'and many walks',
#  'and many walks of',
#  'and marty',
#  'and marty fossil',
#  'and marty fossil fuels',
#  'and marty would',
#  'and marty would be',
#  'and massive',
#  'and massive thank',
#  'and massive thank you',
#  'and may',
#  'and may also',
#  'and may also launch',
#  'and may be',
#  'and may be international',
#  'and may constitute',
#  'and may constitute public',
#  'and may have',
#  'and may have high',
#  'and maybe',
#  'and maybe bag',
#  'and maybe bag of',
#  'and maybe luca',
#  'and maybe luca will',
#  'and measurement',
#  'and measurement of',
#  'and measurement of marketing',
#  'and medical',
#  'and medical leave',
#  'and medical leave act',
#  'and megaphones',
#  'and megaphones on',
#  'and megaphones on second',
#  'and men',
#  'and messed',
#  'and messed up',
#  'and messed up salt',
#  'and metrics',
#  'and metrics software',
#  'and metrics software are',
#  'and might',
#  'and might organize',
#  'and might organize flowers',
#  'and militarized',
#  'and militarized response',
#  'and militarized response circulating',
#  'and millennials',
#  'and millennials is',
#  'and millennials is real',
#  'and miners',
#  'and miners in',
#  'and miners in an',
#  'and mobile',
#  'and mobile division',
#  'and mobile division that',
#  'and mocked',
#  'and mocked political',
#  'and mocked political figures',
#  'and more',
#  'and more difficult',
#  'and more difficult to',
#  'and more locations',
#  'and more locations opened',
#  'and more sausage',
#  'and more sausage finally',
#  'and more seamless',
#  'and more seamless experience',
#  'and more you',
#  'and more you saw',
#  'and morty',
#  'and morty guys',
#  'and morty guys the',
#  'and most',
#  'and most importantly',
#  'and most importantly tasty',
#  'and movie',
#  'and movie bloggers',
#  'and movie bloggers deserves',
#  'and moving',
#  'and moving the',
#  'and moving the needle',
#  'and much',
#  'and much higher',
#  'and much higher in',
#  'and much more',
#  'and much more on',
#  'and murderers',
#  'and murderers is',
#  'and murderers is the',
#  'and musician',
#  'and musician the',
#  'and musician the other',
#  'and musician trying',
#  'and musician trying to',
#  'and my',
#  'and my fingers',
#  'and my fingers in',
#  'and nbctv',
#  'and nbctv on',
#  'and nbctv on the',
#  'and nealmoritz',
#  'and nealmoritz exec',
#  'and nealmoritz exec producer',
#  'and new',
#  'and new services',
#  'and new services uber',
#  'and nicer',
#  'and nicer hotels',
#  'and nicer hotels have',
#  'and niece',
#  'and niece ruth',
#  'and niece ruth mignerey',
#  'and nissan',
#  'and nissan currently',
#  'and nissan currently only',
#  'and nissan seems',
#  'and nissan seems to',
#  'and no',
#  'and no best',
#  'and no best way',
#  'and no entourage',
#  'and no entourage fan',
#  'and no he',
#  'and no he most',
#  'and no he wrote',
#  'and none',
#  'and none packed',
#  'and none packed more',
#  'and nori',
#  'and nori toasted',
#  'and nori toasted seaweed',
#  'and not',
#  'and not to',
#  'and not to be',
#  'and now',
#  'and now new',
#  'and now new york',
#  'and now the',
#  'and now the giant',
#  'and now wish',
#  'and now wish had',
#  'and number',
#  'and number days',
#  'and number days you',
#  'and obfuscated',
#  'and obfuscated reality',
#  'and obfuscated reality many',
#  'and of',
#  'and of course',
#  'and of course his',
#  'and offered',
#  'and offered daniel',
#  'and offered daniel an',
#  'and ohio',
#  'and ohio state',
#  'and ohio state law',
#  'and oil',
#  'and oil that',
#  'and oil that keep',
#  'and okay',
#  'and okay it',
#  'and okay it not',
#  'and on',
#  'and on the',
#  'and on the faces',
#  'and on the web',
#  'and one',
#  'and one brief',
#  'and one brief lesson',
#  'and one for',
#  'and one for best',
#  'and one person',
#  'and one person is',
#  'and online',
#  'and online ads',
#  'and online ads the',
#  'and online and',
#  'and online and now',
#  'and online freedom',
#  'and online freedom of',
#  'and only',
#  'and only highlight',
#  'and only highlight modern',
#  'and only journalists',
#  'and only journalists came',
#  'and open',
#  'and open the',
#  'and open the door',
#  'and operate',
#  'and operate most',
#  'and operate most efficiently',
#  'and or',
#  'and or aren',
#  'and or aren the',
#  'and organizational',
#  'and organizational psychologist',
#  'and organizational psychologist russell',
#  'and os',
#  'and os was',
#  'and os was responding',
#  'and other',
#  'and other companies',
#  'and other companies do',
#  'and other countries',
#  'and other countries in',
#  'and other symptoms',
#  'and other symptoms as',
#  'and others',
#  'and others collapsed',
#  'and others collapsed in',
#  'and others from',
#  'and others from entering',
#  'and others have',
#  'and others have pointed',
#  'and others joining',
#  'and others joining as',
#  'and others might',
#  'and others might have',
#  'and others to',
#  'and others to block',
#  'and our',
#  'and our concern',
#  'and our concern for',
#  'and our isps',
#  'and our isps bulletproof',
#  'and our love',
#  'and our love the',
#  'and our older',
#  'and our older sister',
#  'and our openness',
#  'and our openness and',
#  'and our own',
#  'and our own as',
#  'and outrage',
#  'and outrage charles',
#  'and outrage charles ingram',
#  'and outs',
#  'and outs of',
#  'and outs of this',
#  'and outside',
#  'and outside the',
#  'and outside the courthouse',
#  'and over',
#  'and over the',
#  'and over the top',
#  'and over three',
#  'and over three decades',
#  'and palaces',
#  'and palaces has',
#  'and palaces has been',
#  'and parachuting',
#  'and parachuting and',
#  'and parachuting and wingsuiting',
#  'and paste',
#  'and paste gone',
#  'and paste gone wrong',
#  'and peer',
#  'and peer to',
#  'and peer to peer',
#  'and peers',
#  'and peers so',
#  'and peers so here',
#  'and performing',
#  'and performing live',
#  'and performing live still',
#  'and perhaps',
#  'and perhaps even',
#  'and perhaps even turns',
#  'and permanently',
#  'and permanently stopping',
#  'and permanently stopping the',
#  'and personality',
#  'and personality types',
#  'and personality types set',
#  'and pete',
#  'and pete episode',
#  'and pete episode one',
#  'and pete is',
#  'and pete is dramedy',
#  'and pete the',
#  'and pete the very',
#  'and peter',
#  'and peter talking',
#  'and peter talking the',
#  'and piquant',
#  'and piquant pickled',
#  'and piquant pickled plums',
#  'and plainclothes',
#  'and plainclothes security',
#  'and plainclothes security officers',
#  'and pleasant',
#  'and pleasant who',
#  'and pleasant who are',
#  'and police',
#  'and police brutality',
#  'and police brutality their',
#  'and pop',
#  'and pop singer',
#  'and pop singer who',
#  'and populist',
#  'and populist hits',
#  'and populist hits see',
#  'and possessions',
#  'and possessions are',
#  'and possessions are protected',
#  'and post',
#  'and post the',
#  'and post the pictures',
#  'and potential',
#  'and potential for',
#  'and potential for the',
#  'and poverty',
#  'and poverty in',
#  'and poverty in unprecedented',
#  'and precinct',
#  'and precinct chair',
#  'and precinct chair lied',
#  'and prepared',
#  'and prepared arguments',
#  'and prepared arguments the',
#  'and prestige',
#  'and prestige films',
#  'and prestige films it',
#  'and previously',
#  'and previously voiced',
#  'and previously voiced another',
#  'and price',
#  'and price page',
#  'and price page for',
#  'and prices',
#  'and prices were',
#  'and prices were low',
#  'and prime',
#  'and prime minister',
#  'and prime minister zoran',
#  'and privacy',
#  'and privacy in',
#  'and privacy in the',
#  'and privacy the',
#  'and privacy the fact',
#  'and probably',
#  'and probably just',
#  'and probably just in',
#  'and probate',
#  'and probate court',
#  'and probate court represents',
#  'and products',
#  'and products vastly',
#  'and products vastly differ',
#  'and prosecutors',
#  'and prosecutors have',
#  'and prosecutors have labeled',
#  'and prosecutors refusing',
#  'and prosecutors refusing to',
#  'and prosper',
#  'and prosper mbas',
#  'and prosper mbas bring',
#  'and protecting',
#  'and protecting our',
#  'and protecting our nation',
#  'and protesters',
#  'and protesters away',
#  'and protesters away from',
#  'and prove',
#  'and prove their',
#  'and prove their value',
#  'and provided',
#  'and provided little',
#  'and provided little news',
#  'and provides',
#  'and provides insurance',
#  'and provides insurance in',
#  'and providing',
#  'and providing support',
#  'and providing support advice',
#  'and psychology',
#  'and psychology suggests',
#  'and psychology suggests to',
#  'and pu',
#  'and pu lawyer',
#  'and pu lawyer shang',
#  'and public',
#  'and public keys',
#  'and public keys became',
#  'and puerto',
#  'and puerto rico',
#  'and puerto rico as',
#  'and pundits',
#  'and pundits ever',
#  'and pundits ever since',
#  'and put',
#  'and put eleven',
#  'and put eleven on',
#  'and put security',
#  'and put security at',
#  'and queen',
#  'and queen backed',
#  'and queen backed momentum',
#  'and rather',
#  'and rather speedily',
#  'and rather speedily decreased',
#  'and re',
#  'and re watch',
#  'and re watch it',
#  'and reaffirm',
#  'and reaffirm the',
#  'and reaffirm the importance',
#  'and really',
#  'and really had',
#  'and really had such',
#  'and really who',
#  'and really who would',
#  'and rec',
#  'and rec career',
#  'and rec career and',
#  'and reclaim',
#  'and reclaim territory',
#  'and reclaim territory from',
#  'and regret',
#  'and regret you',
#  'and regret you ve',
#  'and religious',
#  'and religious pluralism',
#  'and religious pluralism is',
#  'and remain',
#  'and remain unforgettable',
#  'and remain unforgettable in',
#  'and reportedly',
#  'and reportedly life',
#  'and reportedly life size',
#  'and reporters',
#  'and reporters tried',
#  'and reporters tried to',
#  'and represented',
#  'and represented dissident',
#  'and represented dissident artist',
#  'and requires',
#  'and requires an',
#  'and requires an analytical',
#  'and research',
#  'and research departments',
#  'and research departments samsung',
#  'and respect',
#  'and respect for',
#  'and respect for another',
#  'and restrained',
#  'and restrained and',
#  'and restrained and unusually',
#  'and retired',
#  'and retired police',
#  'and retired police and',
#  'and right',
#  'and right forcefully',
#  'and right forcefully criticized',
#  'and road',
#  'and road conditions',
#  'and road conditions before',
#  'and rosario',
#  'and rosario dawson',
#  'and rosario dawson dawson',
#  'and rubio',
#  'and rubio strong',
#  'and rubio strong third',
#  'and runs',
#  'and runs away',
#  'and runs away with',
#  'and safe',
#  'and safe environment',
#  'and safe environment for',
#  'and said',
#  'and said that',
#  'and said that he',
#  'and said the',
#  'and said the situation',
#  'and salty',
#  ...]

# %%
# last 50 features
print(vect.get_feature_names()[-1000:-950])
# Out:
# ['you to fly', 'you to fly your', 'you to know', 'you to know quite', 'you to robertdowneyjr', 'you to robertdowneyjr for', 'you to sit', 'you to sit back', 'you to stand', 'you to stand away', 'you to watch', 'you to watch out', 'you twisty', 'you twisty the', 'you twisty the clown', 'you ve', 'you ve created', 'you ve created for', 'you ve destroyed', 'you ve destroyed just', 'you ve done', 'you ve done this', 'you ve experienced', 'you ve experienced similar', 'you ve got', 'you ve got seven', 'you ve gotten', 'you ve gotten yourself', 'you ve made', 'you ve made that', 'you ve sown', 'you ve sown across', 'you venture', 'you venture out', 'you venture out into', 'you want', 'you want to', 'you want to create', 'you want to drive', 'you want to lock', 'you want to rent', 'you want to talk', 'you what', 'you what they', 'you what they are', 'you what they look', 'you when', 'you when done', 'you when done properly', 'you which']

# %% [markdown]
# ### Predict shares

# %%
# Default CountVectorizer
vect = CountVectorizer()
X_dtm = vect.fit_transform(X)

# use Naive Bayes to predict the star rating
nb = MultinomialNB()
pd.Series(cross_val_score(nb, X_dtm, y, cv=10)).describe()
# Out:
# count    10.000000
# mean      0.369444
# std       0.158925
# min       0.111111
# 25%       0.250000
# 50%       0.354167
# 75%       0.500000
# max       0.625000
# dtype: float64

# %%
# define a function that accepts a vectorizer and calculates the accuracy
def tokenize_test(vect):
    X_dtm = vect.fit_transform(X)
    print('Features: ', X_dtm.shape[1])
    nb = MultinomialNB()
    print(pd.Series(cross_val_score(nb, X_dtm, y, cv=10)).describe())

# %%
# include 1-grams and 2-grams
vect = CountVectorizer(ngram_range=(1, 2))
tokenize_test(vect)
# Out:
# Features:  37905
# count    10.000000
# mean      0.379167
# std       0.139512
# min       0.125000
# 25%       0.333333
# 50%       0.375000
# 75%       0.468750
# max       0.625000
# dtype: float64

# %%
X_dtm = vect.fit_transform(X)
nb = MultinomialNB()
pd.Series(cross_val_score(nb, X_dtm, y, cv=10)).mean()
# Out:
# 0.3319444444444445

# %% [markdown]
# # Stopword Removal
#
# - **What:** Remove common words that will likely appear in any text
# - **Why:** They don't tell you much about your text

# %% [markdown]
# - **stop_words:** string {'english'}, list, or None (default)
# - If 'english', a built-in stop word list for English is used.
# - If a list, that list is assumed to contain stop words, all of which will be removed from the resulting tokens.
# - If None, no stop words will be used. max_df can be set to a value in the range [0.7, 1.0) to automatically detect and filter stop words based on intra corpus document frequency of terms.

# %%
# remove English stop words
vect = CountVectorizer(stop_words='english')
tokenize_test(vect)
# Out:
# Features:  7710
# count    10.000000
# mean      0.331944
# std       0.146614
# min       0.111111
# 25%       0.250000
# 50%       0.354167
# 75%       0.468750
# max       0.500000
# dtype: float64

# %%
# set of stop words
print(vect.get_stop_words())
# Out:
# frozenset({'our', 'yours', 'on', 'an', 'co', 'becomes', 'ie', 'to', 'a', 'onto', 'above', 'at', 'behind', 'by', 'thru', 'each', 'empty', 'yourself', 'interest', 'noone', 'has', 'latter', 'me', 'will', 'some', 'so', 'hasnt', 'hereby', 'seemed', 'most', 'after', 'if', 'go', 'their', 'de', 'him', 'another', 'among', 'front', 'amongst', 'now', 'became', 'himself', 'five', 'done', 'sixty', 'system', 'than', 'how', 'ever', 'hundred', 'further', 'less', 'nothing', 'seeming', 'why', 'fill', 'for', 'next', 'indeed', 'must', 'perhaps', 'one', 'without', 'even', 'all', 'am', 'see', 'along', 'anyway', 'should', 'well', 'almost', 'made', 'wherever', 'would', 'bill', 'hers', 'amoungst', 'either', 'what', 'its', 'already', 'whose', 'between', 'un', 'yourselves', 'enough', 'rather', 'becoming', 'when', 'through', 'except', 'cant', 'anything', 'out', 'often', 'put', 'twelve', 'whither', 'eight', 'no', 'over', 'down', 'find', 'three', 'beside', 'cannot', 'i', 'who', 'may', 'else', 'can', 'however', 'much', 'twenty', 'others', 'nine', 'everywhere', 'hence', 'around', 'thence', 'name', 'none', 'seem', 'that', 'something', 'still', 'it', 'sometime', 'many', 'found', 'seems', 'someone', 'thereby', 'more', 'the', 'namely', 'you', 'with', 'nor', 'via', 'due', 'but', 'keep', 'also', 'against', 'she', 'six', 'other', 'from', 'anyone', 'both', 'whereas', 'and', 'top', 'eg', 'once', 'never', 'two', 'herself', 'while', 'as', 'please', 'do', 'is', 'otherwise', 'amount', 'ltd', 'ten', 'such', 'herein', 'become', 'us', 'last', 'own', 'nevertheless', 'themselves', 'anyhow', 'they', 'anywhere', 'hereupon', 'con', 'everyone', 'up', 'per', 'very', 're', 'few', 'back', 'least', 'mill', 'somehow', 'afterwards', 'call', 'myself', 'wherein', 'mostly', 'besides', 'whereby', 'first', 'which', 'give', 'get', 'elsewhere', 'are', 'thus', 'whatever', 'latterly', 'or', 'below', 'same', 'together', 'sometimes', 'always', 'whenever', 'though', 'within', 'describe', 'somewhere', 'since', 'across', 'several', 'nowhere', 'whence', 'any', 'ourselves', 'thereupon', 'too', 'alone', 'move', 'everything', 'during', 'show', 'yet', 'about', 'nobody', 'were', 'therein', 'thin', 'them', 'those', 'four', 'her', 'into', 'sincere', 'my', 'whereupon', 'be', 'of', 'etc', 'whole', 'whom', 'toward', 'not', 'detail', 'although', 'in', 'take', 'mine', 'your', 'meanwhile', 'every', 'these', 'neither', 'because', 'beforehand', 'whoever', 'third', 'fifteen', 'only', 'might', 'forty', 'then', 'before', 'this', 'here', 'beyond', 'off', 'thereafter', 'where', 'cry', 'his', 'had', 'under', 'moreover', 'part', 'couldnt', 'therefore', 'throughout', 'been', 'inc', 'itself', 'he', 'thick', 'we', 'could', 'formerly', 'former', 'side', 'full', 'being', 'fifty', 'serious', 'was', 'whereafter', 'hereafter', 'eleven', 'bottom', 'towards', 'whether', 'again', 'there', 'have', 'until', 'fire', 'upon', 'ours'})

# %% [markdown]
# # Other CountVectorizer Options
#
# - **max_features:** int or None, default=None
# - If not None, build a vocabulary that only consider the top max_features ordered by term frequency across the corpus.

# %%
# remove English stop words and only keep 100 features
vect = CountVectorizer(stop_words='english', max_features=100)
tokenize_test(vect)
# Out:
# Features:  100
# count    10.000000
# mean      0.356944
# std       0.130298
# min       0.125000
# 25%       0.260417
# 50%       0.375000
# 75%       0.468750
# max       0.500000
# dtype: float64

# %%
# all 100 features
print(vect.get_feature_names())
# Out:
# ['01', '10', '11', '15', '1cd', '2015', '2016', '28', 'article', 'australian', 'author', 'best', 'big', 'business', 'campaign', 'com', 'company', 'conversion', 'cystic', 'daniel', 'day', 'description', 'digital', 'don', 'downey', 'entertainment', 'facebook', 'false', 'fibrosis', 'function', 'good', 'hot', 'http', 'https', 'image', 'initpage', 'instagram', 'internal', 'iron', 'jpg', 'jr', 'js', 'just', 'know', 'life', 'like', 'make', 'man', 'marketing', 'mashable', 'media', 'movie', 'movies', 'mshcdn', 'new', 'null', 'oct', 'og', 'old', 'open', 'paris', 'people', 'photo', 'pic', 'platform', 'police', 'posted', 'premiere', 'pu', 'rack', 'rdj', 'return', 'rights', 'rising', 'robert', 'said', 'sailthru', 'says', 'season', 'short_url', 'state', 'time', 'timer', 'title', 'topics', 'travel', 'true', 'trump', 'twitter', 'twttr', 'uncategorized', 'url', 've', 'watercooler', 'way', 'window', 'work', 'world', 'year', 'years']

# %%
# include 1-grams and 2-grams, and limit the number of features
vect = CountVectorizer(ngram_range=(1, 2), max_features=1000)
tokenize_test(vect)
# Out:
# Features:  1000
# count    10.000000
# mean      0.355556
# std       0.127496
# min       0.222222
# 25%       0.250000
# 50%       0.354167
# 75%       0.375000
# max       0.625000
# dtype: float64

# %% [markdown]
# - **min_df:** float in range [0.0, 1.0] or int, default=1
# - When building the vocabulary ignore terms that have a document frequency strictly lower than the given threshold. This value is also called cut-off in the literature. If float, the parameter represents a proportion of documents, integer absolute counts.

# %%
# include 1-grams and 2-grams, and only include terms that appear at least 2 times
vect = CountVectorizer(ngram_range=(1, 2), min_df=2)
tokenize_test(vect)
# Out:
# Features:  7620
# count    10.000000
# mean      0.366667
# std       0.156889
# min       0.125000
# 25%       0.333333
# 50%       0.375000
# 75%       0.468750
# max       0.625000
# dtype: float64

# %% [markdown]
# # Stemming and Lemmatization
#
# **Stemming:**
#
# - **What:** Reduce a word to its base/stem/root form
# - **Why:** Often makes sense to treat related words the same way
# - **Notes:**
#     - Uses a "simple" and fast rule-based approach
#     - Stemmed words are usually not shown to users (used for analysis/indexing)
#     - Some search engines treat words with the same stem as synonyms

# %%
# initialize stemmer
stemmer = SnowballStemmer('english')

# words

# %%
vect = CountVectorizer()
vect.fit(X)
# Out:
# CountVectorizer()

# %%
words = list(vect.vocabulary_.keys())[:100]

# %%
vect.vocabulary_
# Out:
# {'apple': 657,
#  'long': 4182,
#  'controversial': 1694,
#  'ebook': 2338,
#  'case': 1255,
#  'reached': 5560,
#  'final': 2814,
#  'chapter': 1331,
#  'happy': 3257,
#  'ending': 2459,
#  'company': 1559,
#  'wanted': 7388,
#  'supreme': 6671,
#  'court': 1755,
#  'monday': 4558,
#  'rejected': 5667,
#  'appeal': 648,
#  'filed': 2804,
#  'overturn': 4909,
#  'stinging': 6530,
#  'ruling': 5913,
#  'led': 4061,
#  'broad': 1100,
#  'conspiracy': 1653,
#  'major': 4251,
#  'publishers': 5439,
#  'fix': 2844,
#  'price': 5312,
#  'books': 1043,
#  'sold': 6340,
#  'online': 4822,
#  'bookstore': 1044,
#  'decision': 1953,
#  'means': 4370,
#  'choice': 1385,
#  'pay': 5010,
#  '400': 223,
#  'million': 4483,
#  'consumers': 1661,
#  'additional': 443,
#  '50': 252,
#  'legal': 4067,
#  'fees': 2769,
#  'according': 398,
#  'original': 4861,
#  'settlement': 6121,
#  '2014': 153,
#  'marshalled': 4313,
#  'entire': 2495,
#  'tech': 6793,
#  'industry': 3602,
#  'fight': 2798,
#  'fbi': 2749,
#  'verdict': 7289,
#  'damaging': 1884,
#  'reputation': 5743,
#  'consumer': 1660,
#  'friendly': 2985,
#  'brand': 1073,
#  'mention': 4412,
#  'legacy': 4066,
#  'beloved': 919,
#  'founder': 2950,
#  'steve': 6523,
#  'jobs': 3822,
#  'actual': 429,
#  'line': 4131,
#  'fine': 2823,
#  'context': 1674,
#  'total': 6966,
#  '450': 237,
#  'payout': 5015,
#  'equal': 2512,
#  'little': 4155,
#  'half': 3233,
#  'sales': 5944,
#  'generates': 3060,
#  'average': 792,
#  'day': 1917,
#  'based': 865,
#  '75': 314,
#  'billion': 953,
#  'revenue': 5813,
#  'reported': 5723,
#  'recent': 5599,
#  'quarter': 5479,
#  'fixing': 2846,
#  'episode': 2510,
#  'dates': 1907,
#  'late': 4012,
#  '2009': 148,
#  'just': 3870,
#  'ahead': 507,
#  'ipad': 3744,
#  'launch': 4022,
#  'recognizing': 5606,
#  'likely': 4123,
#  'big': 946,
#  'selling': 6074,
#  'point': 5168,
#  'tablet': 6730,
#  'began': 904,
#  'courting': 1758,
#  'book': 1039,
#  'series': 6104,
#  'mails': 4244,
#  'later': 4014,
#  'released': 5680,
#  'government': 3143,
#  'personally': 5062,
#  'persuaded': 5064,
#  'publishing': 5440,
#  'executives': 2603,
#  'think': 6869,
#  'flat': 2858,
#  '99': 344,
#  'pricing': 5316,
#  'previously': 5310,
#  'imposed': 3545,
#  'amazon': 569,
#  'giant': 3089,
#  'world': 7525,
#  'tell': 6808,
#  'new': 4688,
#  'releases': 5681,
#  'eroding': 2524,
#  'value': 7266,
#  'perception': 5041,
#  'products': 5354,
#  'customer': 1856,
#  'minds': 4491,
#  'want': 7387,
#  'practice': 5246,
#  'continue': 1676,
#  'wrote': 7546,
#  'email': 2406,
#  'james': 3782,
#  'murdoch': 4611,
#  'executive': 2602,
#  'news': 4691,
#  'corp': 1724,
#  'owns': 4916,
#  'harper': 3267,
#  'collins': 1499,
#  'ceo': 1296,
#  'sent': 6089,
#  'exec': 2598,
#  'image': 3518,
#  'screengrab': 6026,
#  'mashablethe': 4328,
#  'unhappy': 7178,
#  'unfavorable': 7174,
#  'terms': 6827,
#  'agreed': 501,
#  'signed': 6219,
#  'plan': 5133,
#  'used': 7236,
#  'competition': 1568,
#  'pressure': 5298,
#  'changing': 1323,
#  'structure': 6581,
#  'argued': 681,
#  'helped': 3334,
#  'break': 1078,
#  'potential': 5233,
#  'monopoly': 4563,
#  'market': 4303,
#  'accused': 404,
#  'colluding': 1500,
#  'prices': 5315,
#  'high': 3360,
#  'hachette': 3224,
#  'harpercollins': 3268,
#  'macmillan': 4233,
#  'penguin': 5032,
#  'simon': 6235,
#  'schuster': 6006,
#  'settled': 6120,
#  'department': 2031,
#  'justice': 3871,
#  'going': 3120,
#  'trial': 7050,
#  'armed': 687,
#  'unwavering': 7211,
#  'belief': 913,
#  'rightness': 5840,
#  'courts': 1760,
#  'ready': 5573,
#  'distribute': 2192,
#  'mandated': 4273,
#  'funds': 3007,
#  'kindle': 3929,
#  'customers': 1857,
#  'soon': 6359,
#  'instructed': 3673,
#  'forward': 2944,
#  'spokesperson': 6431,
#  'said': 5937,
#  'statement': 6494,
#  'provided': 5414,
#  'mashable': 4324,
#  'reps': 5739,
#  'did': 2103,
#  'immediately': 3530,
#  'respond': 5774,
#  'request': 5744,
#  'comment': 1531,
#  'loss': 4198,
#  '2013': 152,
#  'says': 5983,
#  'introduced': 3713,
#  'ibookstore': 3493,
#  '2010': 149,
#  'gave': 3047,
#  'injecting': 3635,
#  'needed': 4669,
#  'innovation': 3643,
#  'breaking': 1079,
#  'monopolistic': 4562,
#  'grip': 3186,
#  'time': 6911,
#  've': 7281,
#  'wrong': 7544,
#  'determined': 2078,
#  'analysis': 589,
#  'reason': 5586,
#  'donald': 2231,
#  'trump': 7072,
#  'outrageous': 4887,
#  'statements': 6495,
#  'behavior': 910,
#  'feel': 2765,
#  'familiar': 2712,
#  'women': 7503,
#  'know': 3948,
#  'declarative': 1958,
#  'style': 6603,
#  'trademark': 6997,
#  'shrug': 6206,
#  'reality': 5577,
#  'television': 6806,
#  'political': 5179,
#  'debates': 1939,
#  'outsized': 4890,
#  'role': 5877,
#  'american': 575,
#  'business': 1164,
#  'unforgettable': 7176,
#  'impression': 3548,
#  'targets': 6765,
#  'republicans': 5742,
#  'say': 5981,
#  'cost': 1733,
#  'party': 4982,
#  'eerie': 2361,
#  'familiarity': 2713,
#  'personal': 5060,
#  'encountered': 2454,
#  'man': 4265,
#  'like': 4121,
#  'home': 3403,
#  'work': 7514,
#  'social': 6330,
#  'media': 4378,
#  'relationship': 5674,
#  'extols': 2662,
#  'virtues': 7331,
#  'problem': 5337,
#  'reducing': 5625,
#  'sex': 6124,
#  'objects': 4764,
#  'casts': 1262,
#  'unflappable': 7175,
#  'blames': 985,
#  'woman': 7502,
#  'weaknesses': 7421,
#  'revealed': 5808,
#  'insists': 3657,
#  'responsibility': 5780,
#  'denies': 2022,
#  'deflects': 1990,
#  'turns': 7098,
#  'violent': 7325,
#  'wrongdoing': 7545,
#  'wow': 7536,
#  'tough': 6973,
#  'respect': 5772,
#  'realdonaldtrump': 5576,
#  'march': 4293,
#  '26': 180,
#  '2016': 155,
#  'psychological': 5424,
#  'warfare': 7391,
#  'gaslighting': 3043,
#  'subtle': 6614,
#  'form': 2929,
#  'emotional': 2437,
#  'abuse': 380,
#  'puts': 5465,
#  'victim': 7304,
#  'defensive': 1983,
#  'strategy': 6559,
#  'sees': 6067,
#  'actions': 419,
#  'arguably': 680,
#  'projects': 5369,
#  'voters': 7365,
#  'tuesday': 7081,
#  'florida': 2879,
#  'police': 5175,
#  'charged': 1335,
#  'campaign': 1200,
#  'manager': 4269,
#  'corey': 1722,
#  'lewandowski': 4092,
#  'battery': 878,
#  'female': 2776,
#  'reporter': 5725,
#  'issued': 3763,
#  'tweets': 7109,
#  'refuting': 5643,
#  'video': 7310,
#  'evidence': 2572,
#  'discrediting': 2164,
#  'journalist': 3844,
#  'implying': 3541,
#  'dangerous': 1890,
#  'deadly': 1928,
#  'threat': 6881,
#  'decent': 1949,
#  'assaulting': 721,
#  'look': 4185,
#  'tapes': 6760,
#  '29': 189,
#  'powerful': 5244,
#  'left': 4065,
#  'right': 5839,
#  'forcefully': 2916,
#  'criticized': 1809,
#  'reaction': 5566,
#  'charges': 1337,
#  'victims': 7306,
#  'violence': 7324,
#  'stay': 6502,
#  'silent': 6226,
#  'remarks': 5696,
#  'today': 6933,
#  'demonstrate': 2016,
#  'reasons': 5588,
#  'dawn': 1915,
#  'laguens': 3987,
#  'vice': 7301,
#  'president': 5287,
#  'planned': 5135,
#  'parenthood': 4963,
#  'action': 417,
#  'fund': 3004,
#  'underscore': 7160,
#  'fiction': 2789,
#  'supportive': 6668,
#  'country': 1748,
#  'reporters': 5726,
#  'tape': 6758,
#  'facility': 2688,
#  'changed': 1321,
#  'tune': 7084,
#  'pic': 5095,
#  'twitter': 7112,
#  'com': 1507,
#  'n5815rs1at': 4626,
#  'touching': 6972,
#  'leave': 4056,
#  'conference': 1611,
#  'hand': 3241,
#  'hqb8dl0fhn': 3456,
#  'wednesday': 7430,
#  'group': 3189,
#  'conservative': 1642,
#  'journalists': 3845,
#  'commentators': 1535,
#  'called': 1188,
#  'firing': 2835,
#  'track': 6992,
#  'record': 5609,
#  'making': 4258,
#  'defenders': 1980,
#  'foolish': 2908,
#  'ones': 4817,
#  'nichole': 4702,
#  'bauer': 884,
#  'assistant': 727,
#  'professor': 5358,
#  'science': 6008,
#  'university': 7188,
#  'alabama': 535,
#  'response': 5777,
#  'classic': 1430,
#  'practiced': 5247,
#  'denying': 2028,
#  'previous': 5309,
#  'incontrovertible': 3575,
#  'exists': 2609,
#  'isn': 3758,
#  'exclusive': 2596,
#  'commentary': 1533,
#  'course': 1754,
#  'wasn': 7404,
#  'reference': 5629,
#  'menstruation': 4408,
#  'joked': 3834,
#  'fox': 2953,
#  'anchor': 595,
#  'megyn': 4395,
#  'kelly': 3902,
#  'having': 3285,
#  'blood': 1005,
#  'coming': 1526,
#  'debate': 1938,
#  'certainly': 1299,
#  'use': 7235,
#  'schlonged': 6002,
#  'vulgar': 7371,
#  'term': 6825,
#  'describing': 2047,
#  'badly': 835,
#  'pres': 5279,
#  'barack': 855,
#  'obama': 4758,
#  'beat': 897,
#  'hillary': 3369,
#  'clinton': 1451,
#  '2008': 147,
#  'democratic': 2013,
#  'presidential': 5288,
#  'primary': 5318,
#  'press': 5290,
#  'way': 7417,
#  'convince': 1702,
#  'people': 5037,
#  'opposite': 4841,
#  'definitely': 1986,
#  'accepted': 386,
#  'republican': 5741,
#  'mainstream': 4246,
#  'sort': 6364,
#  'outmoded': 4885,
#  'sexism': 6125,
#  'demonstrates': 2018,
#  'real': 5575,
#  'place': 5128,
#  'discourse': 2161,
#  'instead': 3669,
#  'apologizing': 644,
#  'acknowledging': 411,
#  'question': 5488,
#  'matter': 4345,
#  'offensive': 4786,
#  'doubled': 2246,
#  'obfuscated': 4759,
#  'coworker': 1767,
#  'meaning': 4367,
#  'sexist': 6126,
#  'partner': 4976,
#  'quick': 5492,
#  'end': 2457,
#  'argument': 683,
#  'using': 7241,
#  'word': 7511,
#  'telling': 6809,
#  'don': 2229,
#  'deserve': 2049,
#  'agency': 492,
#  'men': 4406,
#  'denials': 2020,
#  'make': 4253,
#  'appear': 649,
#  'unassailable': 7141,
#  'send': 6081,
#  'entirely': 2496,
#  'different': 2114,
#  'message': 4424,
#  'nature': 4649,
#  'tend': 6817,
#  'support': 6664,
#  'traditional': 7002,
#  'roles': 5878,
#  'believing': 917,
#  'deference': 1984,
#  'male': 4260,
#  'authority': 778,
#  'figure': 2801,
#  'husband': 3488,
#  'faultless': 2740,
#  'effectively': 2367,
#  'takes': 6745,
#  'autonomy': 786,
#  'away': 804,
#  'creating': 1786,
#  'climate': 1446,
#  'explain': 2631,
#  'performed': 5048,
#  'poorly': 5192,
#  'survey': 6685,
#  'nbc': 4656,
#  'wsj': 7547,
#  'poll': 5183,
#  '47': 242,
#  'voting': 7367,
#  'favorability': 2743,
#  'ratings': 5553,
#  'higher': 3361,
#  '59': 282,
#  'registered': 5649,
#  'cnn': 1468,
#  'orc': 4846,
#  'ask': 711,
#  'intended': 3685,
#  'vote': 7362,
#  'don_vito_08': 2230,
#  'picture': 5104,
#  'worth': 7532,
#  'thousand': 6878,
#  'words': 7513,
#  'lyingted': 4225,
#  'nevercruz': 4687,
#  'melaniatrump': 4397,
#  '5bvvewmvf8': 285,
#  '24': 174,
#  'polls': 5185,
#  'fully': 2999,
#  'reflect': 5634,
#  'unseemly': 7203,
#  'attacks': 747,
#  'heidi': 3325,
#  'cruz': 1829,
#  'wife': 7468,
#  'opponent': 4836,
#  'sen': 6079,
#  'ted': 6801,
#  'abortion': 373,
#  'banned': 851,
#  'illegally': 3513,
#  'face': 2681,
#  'punishment': 5452,
#  'clarified': 1426,
#  'hypothetical': 3492,
#  'reversed': 5815,
#  'position': 5214,
#  'clear': 1436,
#  'willing': 7473,
#  'publicly': 5434,
#  'embarrass': 2411,
#  'degrade': 1994,
#  'consider': 1643,
#  'depriving': 2040,
#  'physical': 5093,
#  'freedom': 2967,
#  'power': 5242,
#  'dynamics': 2310,
#  'aren': 677,
#  'abusive': 381,
#  'workplaces': 7522,
#  'relationships': 5675,
#  'fathom': 2738,
#  'mirrors': 4508,
#  'private': 5329,
#  'hell': 3330,
#  'doing': 2222,
#  'control': 1691,
#  'elevate': 2389,
#  'insulate': 3675,
#  'attack': 743,
#  'jackie': 3774,
#  'white': 7457,
#  'emerita': 2424,
#  'psychology': 5426,
#  'senior': 6083,
#  'research': 5751,
#  'scientist': 6011,
#  'center': 1290,
#  'health': 3303,
#  'wellness': 7443,
#  'north': 4731,
#  'carolina': 1239,
#  'greensboro': 3175,
#  'approach': 665,
#  'victimizes': 7305,
#  'playing': 5153,
#  'degradation': 1993,
#  'manipulation': 4278,
#  'present': 5282,
#  'self': 6072,
#  'assured': 735,
#  'knowledgable': 3950,
#  'person': 5058,
#  'silences': 6225,
#  'depressed': 2038,
#  'passive': 4993,
#  'paralyzed': 4960,
#  'feelings': 2767,
#  'doubt': 2248,
#  'insecurity': 3648,
#  'set': 6115,
#  'experience': 2624,
#  'worries': 7528,
#  'tactics': 6736,
#  'display': 2179,
#  'consciously': 1637,
#  'subconsciously': 6607,
#  'lead': 4036,
#  'endorse': 2462,
#  'harmful': 3266,
#  'stereotypes': 6522,
#  'engage': 2471,
#  'particularly': 4973,
#  'threatened': 6882,
#  'demographic': 2015,
#  'change': 1320,
#  'evolving': 2576,
#  'gender': 3056,
#  'inspire': 3661,
#  'justified': 3873,
#  'clinging': 1449,
#  'deserved': 2050,
#  'elevated': 2390,
#  'status': 6501,
#  'makes': 4257,
#  'offering': 4789,
#  'public': 5433,
#  'performance': 5046,
#  'fallout': 2708,
#  'unconscionable': 7149,
#  'london': 4181,
#  'month': 4566,
#  'dog': 2218,
#  'sized': 6257,
#  'rabbit': 5506,
#  'desperate': 2060,
#  'need': 4668,
#  'atlas': 741,
#  'permanent': 5053,
#  'story': 6546,
#  'went': 7445,
#  'global': 3106,
#  'including': 3569,
#  'canada': 1204,
#  'france': 2956,
#  'started': 6487,
#  'reaching': 5562,
#  'scottish': 6020,
#  'society': 6332,
#  'prevention': 5306,
#  'cruelty': 1825,
#  'animals': 613,
#  'thanks': 6851,
#  'jen': 3804,
#  'hislop': 3381,
#  'ayrshire': 810,
#  'adorable': 456,
#  'bunny': 1149,
#  'native': 4646,
#  'scotland': 6018,
#  'buggy': 1131,
#  'facebook': 2682,
#  'spcajen': 6389,
#  'financial': 2819,
#  'fraud': 2962,
#  'investigator': 3724,
#  'told': 6937,
#  'charity': 1339,
#  'burst': 1158,
#  'tears': 6789,
#  'got': 3136,
#  'phone': 5081,
#  'saying': 5982,
#  'chosen': 1396,
#  'cried': 1800,
#  'collected': 1494,
#  '43': 231,
#  'year': 7567,
#  'old': 4808,
#  'bunnies': 1148,
#  'currently': 1851,
#  'rex': 5823,
#  'named': 4633,
#  'coconut': 1475,
#  'looking': 4188,
#  'growing': 3193,
#  'summer': 6645,
#  'house': 3448,
#  'heating': 3316,
#  'air': 519,
#  'conditioning': 1606,
#  'accommodation': 394,
#  'large': 4005,
#  'garden': 3037,
#  'enclosure': 2451,
#  'run': 5915,
#  'perfect': 5042,
#  'addition': 442,
#  'family': 2715,
#  'thing': 6867,
#  'hello': 3332,
#  'atilla': 738,
#  'bun': 1146,
#  'binky': 958,
#  'master': 4334,
#  'jazz': 3797,
#  'paws': 5009,
#  'worry': 7529,
#  'atty': 760,
#  'short': 6178,
#  'digital': 2122,
#  'marketing': 4306,
#  'experts': 2630,
#  'diverse': 2197,
#  'skill': 6260,
#  'sophisticated': 6361,
#  'grasp': 3163,
#  'available': 787,
#  'channels': 1326,
#  'ability': 370,
#  'identify': 3502,
#  'opportunities': 4838,
#  'basic': 867,
#  'skills': 6261,
#  'brilliant': 1093,
#  'marketer': 4304,
#  'possess': 5218,
#  'balance': 841,
#  'critical': 1806,
#  'creative': 1789,
#  'thinking': 6870,
#  'order': 4848,
#  'drive': 2276,
#  'measurable': 4372,
#  'success': 6618,
#  'asked': 712,
#  '15': 72,
#  'members': 4401,
#  'young': 7580,
#  'entrepreneur': 2501,
#  'council': 1740,
#  'yec': 7569,
#  'hiring': 3380,
#  'marketers': 4305,
#  'best': 932,
#  'answers': 632,
#  'paid': 4939,
#  'advertising': 468,
#  'expertise': 2629,
#  'hire': 3377,
#  'versed': 7293,
#  'especially': 2526,
#  'similar': 6234,
#  'platform': 5142,
#  'uses': 7240,
#  'regularly': 5652,
#  'able': 371,
#  'understand': 7161,
#  'implement': 3540,
#  'analytics': 592,
#  'insights': 3654,
#  'create': 1783,
#  'lookalike': 4186,
#  'custom': 1855,
#  'audiences': 764,
#  'experiment': 2627,
#  'test': 6836,
#  'images': 3520,
#  'secure': 6059,
#  'knowledge': 3951,
#  'overall': 4896,
#  'landscape': 3995,
#  'budget': 1126,
#  'saving': 5978,
#  'space': 6384,
#  'sure': 6672,
#  'talent': 6747,
#  'knows': 3953,
#  'ins': 3647,
#  'outs': 4888,
#  'popular': 5198,
#  'easy': 2335,
#  'miles': 4471,
#  'jennings': 3806,
#  'recruiter': 5616,
#  'web': 7427,
#  'developers': 2085,
#  'data': 1904,
#  'scientists': 6012,
#  'ai': 508,
#  'hired': 3378,
#  'years': 7568,
#  'outsourced': 4891,
#  'successfully': 6620,
#  'better': 937,
#  'turn': 7093,
#  'closing': 1459,
#  'deals': 1933,
#  'directly': 2141,
#  'sell': 6073,
#  'll': 4160,
#  'wasting': 7407,
#  'valuable': 7265,
#  'dollars': 2224,
#  'generating': 3061,
#  'qualified': 5474,
#  'team': 6786,
#  'mark': 4301,
#  'cenicola': 1289,
#  'bannerview': 852,
#  'specific': 6402,
#  'channel': 1324,
#  'extol': 2661,
#  'conceivable': 1593,
#  'seo': 6091,
#  'sem': 6075,
#  'key': 3909,
#  'successful': 6619,
#  'focusing': 2894,
#  'really': 5582,
#  'understanding': 7162,
#  'deeply': 1971,
#  'leveraging': 4090,
#  'example': 2583,
#  'helping': 3336,
#  'local': 4167,
#  'businesses': 1165,
#  'pinterest': 5112,
#  'interesting': 3695,
#  'drivers': 2278,
#  'ecommerce': 2340,
#  'traffic': 7006,
#  'focus': 2892,
#  'intricate': 3711,
#  'client': 1443,
#  'google': 3131,
#  'maps': 4292,
#  'yelp': 7572,
#  'trevor': 7049,
#  'sumner': 6647,
#  'localvox': 4170,
#  'objectively': 4763,
#  'usually': 7245,
#  'passionate': 4992,
#  'workers': 7516,
#  'office': 4792,
#  'passion': 4991,
#  'cloud': 1460,
#  'judgment': 3856,
#  'measurement': 4374,
#  'theories': 6862,
#  'initiatives': 3632,
#  'separate': 6093,
#  'navigate': 4652,
#  'objective': 4762,
#  'eye': 2673,
#  'actually': 430,
#  'works': 7523,
#  'hoped': 3423,
#  'wesley': 7447,
#  'mathews': 4342,
#  'level': 4087,
#  'execute': 2600,
#  'analyze': 593,
#  'drip': 2275,
#  'campaigns': 1201,
#  'inbound': 3559,
#  'driving': 2280,
#  'generation': 3062,
#  'come': 1515,
#  'initial': 3629,
#  'innovative': 3644,
#  'engagement': 2472,
#  'cpc': 1769,
#  'intrigues': 3712,
#  'examine': 2580,
#  'incoming': 3572,
#  'robust': 5864,
#  'great': 3168,
#  'automation': 783,
#  'sending': 6082,
#  'flock': 2874,
#  'gathers': 3046,
#  'written': 7543,
#  'communication': 1550,
#  'varies': 7274,
#  'depending': 2033,
#  'seven': 6122,
#  'emails': 2408,
#  'deep': 1969,
#  'lot': 4200,
#  'variation': 7272,
#  'requires': 5749,
#  'analytical': 591,
#  'mindset': 4492,
#  'strategic': 6555,
#  'exceptional': 2587,
#  'happens': 3255,
#  'art': 698,
#  'expands': 2615,
#  'fundamental': 3005,
#  'conversion': 1699,
#  'eran': 2521,
#  'eyal': 2672,
#  'springleap': 6444,
#  '11': 50,
#  'things': 6868,
#  'startup': 6490,
#  'mix': 4528,
#  'creativity': 1790,
#  'abilities': 369,
#  'candidate': 1211,
#  'capable': 1221,
#  'excited': 2590,
#  'candidates': 1212,
#  'purely': 5458,
#  'important': 3543,
#  'bring': 1094,
#  'program': 5361,
#  'allows': 560,
#  'beautiful': 899,
#  'inform': 3620,
#  'future': 3017,
#  'strategies': 6556,
#  'kayla': 3897,
#  'wagner': 7375,
#  'faires': 2697,
#  'revel': 5811,
#  'interactive': 3692,
#  'good': 3128,
#  'copy': 1716,
#  'visual': 7343,
#  'storytelling': 6548,
#  'driven': 2277,
#  'medium': 4383,
#  'unlike': 7191,
#  'heart': 3310,
#  'won': 7504,
#  'double': 2245,
#  'clicked': 1441,
#  'relevant': 5684,
#  'visuals': 7345,
#  'pull': 5445,
#  'strings': 6576,
#  'manipulate': 4277,
#  'elements': 2388,
#  'alex': 544,
#  'frias': 2980,
#  'likable': 4120,
#  'personality': 5061,
#  'building': 1135,
#  'huge': 3469,
#  'component': 1582,
#  'trying': 7077,
#  'connect': 1630,
#  'bloggers': 1003,
#  'influencers': 3616,
#  'stand': 6471,
#  'command': 1527,
#  'attention': 756,
#  'pitched': 5121,
#  'equivalent': 2518,
#  'talking': 6751,
#  'brick': 1089,
#  'wall': 7384,
#  'outgoing': 4880,
#  'pleasant': 5155,
#  'applies': 661,
#  'maintaining': 4249,
#  'plays': 5154,
#  'overlooked': 4901,
#  'jonathan': 3839,
#  'domination': 2228,
#  '14': 69,
#  'mobile': 4533,
#  'trends': 7047,
#  'dominate': 2227,
#  'wordpress': 7512,
#  'platforms': 5143,
#  'built': 1136,
#  'vital': 7346,
#  'technical': 6794,
#  'tool': 6953,
#  'add': 438,
#  'toolbox': 6954,
#  'manage': 4266,
#  'blog': 1001,
#  'website': 7428,
#  'helps': 3337,
#  'continually': 1675,
#  'educate': 2357,
#  'plug': 5162,
#  'functionality': 3002,
#  'useful': 7237,
#  'speeds': 6409,
#  'content': 1669,
#  'production': 5351,
#  'angela': 606,
#  ...}

# %%
# stem each word
print([stemmer.stem(word) for word in words])
# Out:
# ['appl', 'long', 'and', 'controversi', 'ebook', 'case', 'has', 'reach', 'it', 'final', 'chapter', 'it', 'not', 'the', 'happi', 'end', 'compani', 'want', 'suprem', 'court', 'on', 'monday', 'reject', 'an', 'appeal', 'file', 'by', 'to', 'overturn', 'sting', 'rule', 'that', 'led', 'broad', 'conspiraci', 'with', 'sever', 'major', 'publish', 'fix', 'price', 'of', 'book', 'sold', 'through', 'onlin', 'bookstor', 'decis', 'mean', 'now', 'no', 'choic', 'but', 'pay', 'out', '400', 'million', 'consum', 'addit', '50', 'in', 'legal', 'fee', 'accord', 'origin', 'settlement', '2014', 'see', 'also', 'here', 'how', 'marshal', 'entir', 'tech', 'industri', 'fight', 'fbi', 'for', 'verdict', 'is', 'more', 'damag', 'reput', 'as', 'consum', 'friend', 'brand', 'mention', 'legaci', 'belov', 'founder', 'steve', 'job', 'than', 'actual', 'bottom', 'line', 'put', 'fine', 'context']

# %% [markdown]
# **Lemmatization**
#
# - **What:** Derive the canonical form ('lemma') of a word
# - **Why:** Can be better than stemming
# - **Notes:** Uses a dictionary-based approach (slower than stemming)

# %%
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /home/david/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# assume every word is a noun
print([wordnet_lemmatizer.lemmatize(word) for word in words])
# Out:
# ['apple', 'long', 'and', 'controversial', 'ebook', 'case', 'ha', 'reached', 'it', 'final', 'chapter', 'it', 'not', 'the', 'happy', 'ending', 'company', 'wanted', 'supreme', 'court', 'on', 'monday', 'rejected', 'an', 'appeal', 'filed', 'by', 'to', 'overturn', 'stinging', 'ruling', 'that', 'led', 'broad', 'conspiracy', 'with', 'several', 'major', 'publisher', 'fix', 'price', 'of', 'book', 'sold', 'through', 'online', 'bookstore', 'decision', 'mean', 'now', 'no', 'choice', 'but', 'pay', 'out', '400', 'million', 'consumer', 'additional', '50', 'in', 'legal', 'fee', 'according', 'original', 'settlement', '2014', 'see', 'also', 'here', 'how', 'marshalled', 'entire', 'tech', 'industry', 'fight', 'fbi', 'for', 'verdict', 'is', 'more', 'damaging', 'reputation', 'a', 'consumer', 'friendly', 'brand', 'mention', 'legacy', 'beloved', 'founder', 'steve', 'job', 'than', 'actual', 'bottom', 'line', 'put', 'fine', 'context']

# %%
# assume every word is a verb
print([wordnet_lemmatizer.lemmatize(word,pos='v') for word in words])
# Out:
# ['apple', 'long', 'and', 'controversial', 'ebook', 'case', 'have', 'reach', 'its', 'final', 'chapter', 'it', 'not', 'the', 'happy', 'end', 'company', 'want', 'supreme', 'court', 'on', 'monday', 'reject', 'an', 'appeal', 'file', 'by', 'to', 'overturn', 'sting', 'rule', 'that', 'lead', 'broad', 'conspiracy', 'with', 'several', 'major', 'publishers', 'fix', 'price', 'of', 'book', 'sell', 'through', 'online', 'bookstore', 'decision', 'mean', 'now', 'no', 'choice', 'but', 'pay', 'out', '400', 'million', 'consumers', 'additional', '50', 'in', 'legal', 'fee', 'accord', 'original', 'settlement', '2014', 'see', 'also', 'here', 'how', 'marshal', 'entire', 'tech', 'industry', 'fight', 'fbi', 'for', 'verdict', 'be', 'more', 'damage', 'reputation', 'as', 'consumer', 'friendly', 'brand', 'mention', 'legacy', 'beloved', 'founder', 'steve', 'job', 'than', 'actual', 'bottom', 'line', 'put', 'fine', 'context']

# %%
# define a function that accepts text and returns a list of lemmas
def split_into_lemmas(text):
    text = text.lower()
    words = text.split()
    return [wordnet_lemmatizer.lemmatize(word) for word in words]

# %%
# use split_into_lemmas as the feature extraction function (WARNING: SLOW!)
vect = CountVectorizer(analyzer=split_into_lemmas)
tokenize_test(vect)
# Out:
# Features:  10208
# count    10.000000
# mean      0.379167
# std       0.108584
# min       0.222222
# 25%       0.281250
# 50%       0.375000
# 75%       0.486111
# max       0.500000
# dtype: float64

# %% [markdown]
# #  Term Frequency-Inverse Document Frequency (TF-IDF)
#
# - **What:** Computes "relative frequency" that a word appears in a document compared to its frequency across all documents
# - **Why:** More useful than "term frequency" for identifying "important" words in each document (high frequency in that document, low frequency in other documents)
# - **Notes:** Used for search engine scoring, text summarization, document clustering

# %%
# example documents
simple_train = ['call you tonight asap', 'Call me a cab', 'please call me... PLEASE!']

# %%
# Term Frequency
vect = CountVectorizer()
tf = pd.DataFrame(vect.fit_transform(simple_train).toarray(), columns=vect.get_feature_names())
tf
# Out:
#    asap  cab  call  me  please  tonight  you
# 0     1    0     1   0       0        1    1
# 1     0    1     1   1       0        0    0
# 2     0    0     1   1       2        0    0

# %%
# Document Frequency
vect = CountVectorizer(binary=True)
df_ = vect.fit_transform(simple_train).toarray().sum(axis=0)
pd.DataFrame(df_.reshape(1, 6), columns=vect.get_feature_names())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-023794179114> in <module>
#       2 vect = CountVectorizer(binary=True)
#       3 df_ = vect.fit_transform(simple_train).toarray().sum(axis=0)
# ----> 4 pd.DataFrame(df_.reshape(1, 6), columns=vect.get_feature_names())
#
# ValueError: cannot reshape array of size 7 into shape (1,6)

# %%
# Term Frequency-Inverse Document Frequency (simple version)
tf/df_
# Out:
#    cab      call   me  please  tonight  you
# 0  0.0  0.333333  0.0     0.0      1.0  1.0
# 1  1.0  0.333333  0.5     0.0      0.0  0.0
# 2  0.0  0.333333  0.5     2.0      0.0  0.0

# %%
# TfidfVectorizer
vect = TfidfVectorizer()
pd.DataFrame(vect.fit_transform(simple_train).toarray(), columns=vect.get_feature_names())
# Out:
#        asap       cab      call        me    please   tonight       you
# 0  0.546454  0.000000  0.322745  0.000000  0.000000  0.546454  0.546454
# 1  0.000000  0.720333  0.425441  0.547832  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.266075  0.342620  0.901008  0.000000  0.000000

# %% [markdown]
# **More details:** [TF-IDF is about what matters](http://planspace.org/20150524-tfidf_is_about_what_matters/)

# %% [markdown]
# # Using TF-IDF to Summarize a text

# %%
# create a document-term matrix using TF-IDF
vect = TfidfVectorizer(stop_words='english')
dtm = vect.fit_transform(X)
features = vect.get_feature_names()
dtm.shape
# Out:
# (82, 7710)

# %%
# choose a random text
review_id = 40
review_text = X[review_id]
review_length = len(review_text)

# %%
# create a dictionary of words and their TF-IDF scores
word_scores = {}
for word in vect.vocabulary_.keys():
    word = word.lower()
    if word in features:
        word_scores[word] = dtm[review_id, features.index(word)]

# %%
word_scores
# Out:
# {'apple': 0.0,
#  'long': 0.0,
#  'controversial': 0.03422888118486373,
#  'ebook': 0.0,
#  'case': 0.0,
#  'reached': 0.0,
#  'final': 0.0,
#  'chapter': 0.0,
#  'happy': 0.0,
#  'ending': 0.0,
#  'company': 0.0,
#  'wanted': 0.0,
#  'supreme': 0.0,
#  'court': 0.0,
#  'monday': 0.022611190267357657,
#  'rejected': 0.0,
#  'appeal': 0.0,
#  'filed': 0.0,
#  'overturn': 0.0,
#  'stinging': 0.0,
#  'ruling': 0.0,
#  'led': 0.0,
#  'broad': 0.0,
#  'conspiracy': 0.06389919057695065,
#  'major': 0.0,
#  'publishers': 0.0,
#  'fix': 0.0,
#  'price': 0.0,
#  'books': 0.0,
#  'sold': 0.0,
#  'online': 0.0,
#  'bookstore': 0.0,
#  'decision': 0.0,
#  'means': 0.0,
#  'choice': 0.0,
#  'pay': 0.0,
#  '400': 0.0,
#  'million': 0.0,
#  'consumers': 0.0,
#  'additional': 0.0,
#  '50': 0.0,
#  'legal': 0.0,
#  'fees': 0.0,
#  'according': 0.020485752571699135,
#  'original': 0.0,
#  'settlement': 0.0,
#  '2014': 0.0,
#  'marshalled': 0.0,
#  'entire': 0.0,
#  'tech': 0.0,
#  'industry': 0.0,
#  'fight': 0.06389919057695065,
#  'fbi': 0.0,
#  'verdict': 0.0,
#  'damaging': 0.0,
#  'reputation': 0.0,
#  'consumer': 0.0,
#  'friendly': 0.0,
#  'brand': 0.0,
#  'mention': 0.0,
#  'legacy': 0.0,
#  'beloved': 0.0,
#  'founder': 0.0,
#  'steve': 0.0,
#  'jobs': 0.0,
#  'actual': 0.0,
#  'line': 0.0,
#  'fine': 0.0,
#  'context': 0.0,
#  'total': 0.0,
#  '450': 0.0,
#  'payout': 0.0,
#  'equal': 0.0,
#  'little': 0.019198125919320547,
#  'half': 0.0,
#  'sales': 0.0,
#  'generates': 0.0,
#  'average': 0.0,
#  'day': 0.0,
#  'based': 0.0,
#  '75': 0.0,
#  'billion': 0.0,
#  'revenue': 0.0,
#  'reported': 0.02324536330829197,
#  'recent': 0.0,
#  'quarter': 0.0,
#  'fixing': 0.0,
#  'episode': 0.0,
#  'dates': 0.0,
#  'late': 0.02552464920468038,
#  '2009': 0.0,
#  'just': 0.0,
#  'ahead': 0.0,
#  'ipad': 0.0,
#  'launch': 0.0,
#  'recognizing': 0.0,
#  'likely': 0.0,
#  'big': 0.0,
#  'selling': 0.0,
#  'point': 0.02324536330829197,
#  'tablet': 0.0,
#  'began': 0.0,
#  'courting': 0.0,
#  'book': 0.0,
#  'series': 0.0,
#  'mails': 0.0,
#  'later': 0.0,
#  'released': 0.0,
#  'government': 0.0,
#  'personally': 0.0,
#  'persuaded': 0.0,
#  'publishing': 0.0,
#  'executives': 0.03422888118486373,
#  'think': 0.021477411815708954,
#  'flat': 0.0,
#  '99': 0.0,
#  'pricing': 0.0,
#  'previously': 0.02552464920468038,
#  'imposed': 0.0,
#  'amazon': 0.0,
#  'giant': 0.0,
#  'world': 0.0,
#  'tell': 0.0,
#  'new': 0.022953509621818226,
#  'releases': 0.0,
#  'eroding': 0.0,
#  'value': 0.0,
#  'perception': 0.0,
#  'products': 0.0,
#  'customer': 0.0,
#  'minds': 0.0,
#  'want': 0.01809080135998102,
#  'practice': 0.0,
#  'continue': 0.0,
#  'wrote': 0.0,
#  'email': 0.0,
#  'james': 0.0,
#  'murdoch': 0.0,
#  'executive': 0.0,
#  'news': 0.0,
#  'corp': 0.0,
#  'owns': 0.0,
#  'harper': 0.0,
#  'collins': 0.0,
#  'ceo': 0.0,
#  'sent': 0.0,
#  'exec': 0.0,
#  'image': 0.0,
#  'screengrab': 0.0,
#  'mashablethe': 0.0,
#  'unhappy': 0.0,
#  'unfavorable': 0.0,
#  'terms': 0.0,
#  'agreed': 0.0,
#  'signed': 0.0,
#  'plan': 0.0,
#  'used': 0.036885979427442074,
#  'competition': 0.0,
#  'pressure': 0.0,
#  'changing': 0.0,
#  'structure': 0.0,
#  'argued': 0.0,
#  'helped': 0.0,
#  'break': 0.027515796678896375,
#  'potential': 0.022611190267357657,
#  'monopoly': 0.0,
#  'market': 0.0,
#  'accused': 0.0,
#  'colluding': 0.0,
#  'prices': 0.0,
#  'high': 0.022024037740610496,
#  'hachette': 0.0,
#  'harpercollins': 0.0,
#  'macmillan': 0.0,
#  'penguin': 0.0,
#  'simon': 0.0,
#  'schuster': 0.0,
#  'settled': 0.0,
#  'department': 0.0,
#  'justice': 0.0,
#  'going': 0.01809080135998102,
#  'trial': 0.0,
#  'armed': 0.0,
#  'unwavering': 0.0,
#  'belief': 0.0,
#  'rightness': 0.0,
#  'courts': 0.0,
#  'ready': 0.0,
#  'distribute': 0.0,
#  'mandated': 0.0,
#  'funds': 0.0,
#  'kindle': 0.0,
#  'customers': 0.0,
#  'soon': 0.0,
#  'instructed': 0.0,
#  'forward': 0.0,
#  'spokesperson': 0.0,
#  'said': 0.06755364528177144,
#  'statement': 0.0,
#  'provided': 0.0,
#  'mashable': 0.0,
#  'reps': 0.0,
#  'did': 0.0,
#  'immediately': 0.0,
#  'respond': 0.0,
#  'request': 0.0,
#  'comment': 0.0,
#  'loss': 0.030181643795892305,
#  '2013': 0.0,
#  'says': 0.0,
#  'introduced': 0.0,
#  'ibookstore': 0.0,
#  '2010': 0.0,
#  'gave': 0.0,
#  'injecting': 0.0,
#  'needed': 0.0,
#  'innovation': 0.0,
#  'breaking': 0.0,
#  'monopolistic': 0.0,
#  'grip': 0.0,
#  'time': 0.0,
#  've': 0.0,
#  'wrong': 0.0,
#  'determined': 0.030181643795892305,
#  'analysis': 0.0,
#  'reason': 0.0,
#  'donald': 0.0,
#  'trump': 0.02552464920468038,
#  'outrageous': 0.0,
#  'statements': 0.0,
#  'behavior': 0.0,
#  'feel': 0.0,
#  'familiar': 0.0,
#  'women': 0.0,
#  'know': 0.036885979427442074,
#  'declarative': 0.0,
#  'style': 0.0,
#  'trademark': 0.0,
#  'shrug': 0.0,
#  'reality': 0.0,
#  'television': 0.0,
#  'political': 0.024689884857606426,
#  'debates': 0.0,
#  'outsized': 0.0,
#  'role': 0.0,
#  'american': 0.024689884857606426,
#  'business': 0.022611190267357657,
#  'unforgettable': 0.0,
#  'impression': 0.0,
#  'targets': 0.0,
#  'republicans': 0.0,
#  'say': 0.019198125919320547,
#  'cost': 0.0,
#  'party': 0.07657394761404114,
#  'eerie': 0.0,
#  'familiarity': 0.0,
#  'personal': 0.0,
#  'encountered': 0.0,
#  'man': 0.0,
#  'like': 0.038319539506576815,
#  'home': 0.0,
#  'work': 0.0,
#  'social': 0.0,
#  'media': 0.0,
#  'relationship': 0.0,
#  'extols': 0.0,
#  'virtues': 0.0,
#  'problem': 0.0,
#  'reducing': 0.0,
#  'sex': 0.0,
#  'objects': 0.0,
#  'casts': 0.0,
#  'unflappable': 0.0,
#  'blames': 0.0,
#  'woman': 0.0,
#  'weaknesses': 0.0,
#  'revealed': 0.0,
#  'insists': 0.0,
#  'responsibility': 0.0,
#  'denies': 0.0,
#  'deflects': 0.0,
#  'turns': 0.0,
#  'violent': 0.0,
#  'wrongdoing': 0.0,
#  'wow': 0.0,
#  'tough': 0.0,
#  'respect': 0.0,
#  'realdonaldtrump': 0.0,
#  'march': 0.0,
#  '26': 0.0,
#  '2016': 0.054042916225417154,
#  'psychological': 0.0,
#  'warfare': 0.0,
#  'gaslighting': 0.0,
#  'subtle': 0.0,
#  'form': 0.0,
#  'emotional': 0.0,
#  'abuse': 0.0,
#  'puts': 0.0,
#  'victim': 0.0,
#  'defensive': 0.0,
#  'strategy': 0.0,
#  'sees': 0.0,
#  'actions': 0.0,
#  'arguably': 0.0,
#  'projects': 0.0,
#  'voters': 0.0,
#  'tuesday': 0.09573899460802766,
#  'florida': 0.0,
#  'police': 0.0,
#  'charged': 0.0,
#  'campaign': 0.05816452531243449,
#  'manager': 0.0,
#  'corey': 0.0,
#  'lewandowski': 0.0,
#  'battery': 0.0,
#  'female': 0.0,
#  'reporter': 0.0,
#  'issued': 0.0,
#  'tweets': 0.0,
#  'refuting': 0.0,
#  'video': 0.0,
#  'evidence': 0.0,
#  'discrediting': 0.0,
#  'journalist': 0.0,
#  'implying': 0.0,
#  'dangerous': 0.0,
#  'deadly': 0.0,
#  'threat': 0.0,
#  'decent': 0.0,
#  'assaulting': 0.0,
#  'look': 0.0,
#  'tapes': 0.0,
#  '29': 0.0,
#  'powerful': 0.0,
#  'left': 0.026457836350189442,
#  'right': 0.0,
#  'forcefully': 0.0,
#  'criticized': 0.0,
#  'reaction': 0.0,
#  'charges': 0.0,
#  'victims': 0.0,
#  'violence': 0.0,
#  'stay': 0.0,
#  'silent': 0.0,
#  'remarks': 0.0,
#  'today': 0.0,
#  'demonstrate': 0.0,
#  'reasons': 0.0,
#  'dawn': 0.0,
#  'laguens': 0.0,
#  'vice': 0.0,
#  'president': 0.020966077411903563,
#  'planned': 0.0,
#  'parenthood': 0.0,
#  'action': 0.0,
#  'fund': 0.0,
#  'underscore': 0.0,
#  'fiction': 0.0,
#  'supportive': 0.0,
#  'country': 0.0,
#  'reporters': 0.024689884857606426,
#  'tape': 0.0,
#  'facility': 0.0,
#  'changed': 0.0,
#  'tune': 0.0,
#  'pic': 0.016532278802324614,
#  'twitter': 0.02663961152085429,
#  'com': 0.013319805760427145,
#  'n5815rs1at': 0.0,
#  'touching': 0.0,
#  'leave': 0.0,
#  'conference': 0.0,
#  'hand': 0.0,
#  'hqb8dl0fhn': 0.0,
#  'wednesday': 0.0,
#  'group': 0.04404807548122099,
#  'conservative': 0.0,
#  'journalists': 0.0,
#  'commentators': 0.0,
#  'called': 0.022024037740610496,
#  'firing': 0.0,
#  'track': 0.0,
#  'record': 0.0,
#  'making': 0.0,
#  'defenders': 0.0,
#  'foolish': 0.0,
#  'ones': 0.0,
#  'nichole': 0.0,
#  'bauer': 0.0,
#  'assistant': 0.0,
#  'professor': 0.0,
#  'science': 0.0,
#  'university': 0.0,
#  'alabama': 0.0,
#  'response': 0.0,
#  'classic': 0.0,
#  'practiced': 0.0,
#  'denying': 0.0,
#  'previous': 0.0,
#  'incontrovertible': 0.0,
#  'exists': 0.0,
#  'isn': 0.020485752571699135,
#  'exclusive': 0.0,
#  'commentary': 0.0,
#  'course': 0.0,
#  'wasn': 0.027515796678896375,
#  'reference': 0.0,
#  'menstruation': 0.0,
#  'joked': 0.0,
#  'fox': 0.0,
#  'anchor': 0.0,
#  'megyn': 0.0,
#  'kelly': 0.0,
#  'having': 0.0,
#  'blood': 0.0,
#  'coming': 0.0,
#  'debate': 0.0,
#  'certainly': 0.0,
#  'use': 0.0,
#  'schlonged': 0.0,
#  'vulgar': 0.0,
#  'term': 0.0,
#  'describing': 0.0,
#  'badly': 0.0,
#  'pres': 0.0,
#  'barack': 0.0,
#  'obama': 0.0,
#  'beat': 0.0,
#  'hillary': 0.08621136673973356,
#  'clinton': 0.19261057675227464,
#  '2008': 0.0,
#  'democratic': 0.09584878586542596,
#  'presidential': 0.0,
#  'primary': 0.06389919057695065,
#  'press': 0.0,
#  'way': 0.014541131328108622,
#  'convince': 0.0,
#  'people': 0.027412733962069332,
#  'opposite': 0.0,
#  'definitely': 0.0,
#  'accepted': 0.0,
#  'republican': 0.0,
#  'mainstream': 0.0,
#  'sort': 0.0,
#  'outmoded': 0.0,
#  'sexism': 0.0,
#  'demonstrates': 0.0,
#  'real': 0.0,
#  'place': 0.0,
#  'discourse': 0.0,
#  'instead': 0.0,
#  'apologizing': 0.0,
#  'acknowledging': 0.0,
#  'question': 0.0,
#  'matter': 0.0,
#  'offensive': 0.0,
#  'doubled': 0.0,
#  'obfuscated': 0.0,
#  'coworker': 0.0,
#  'meaning': 0.0,
#  'sexist': 0.0,
#  'partner': 0.0,
#  'quick': 0.030181643795892305,
#  'end': 0.0,
#  'argument': 0.0,
#  'using': 0.02324536330829197,
#  'word': 0.0,
#  'telling': 0.0,
#  'don': 0.03306455760464923,
#  'deserve': 0.0,
#  'agency': 0.0,
#  'men': 0.0,
#  'denials': 0.0,
#  'make': 0.0,
#  'appear': 0.0,
#  'unassailable': 0.0,
#  'send': 0.0,
#  'entirely': 0.0,
#  'different': 0.0,
#  'message': 0.0,
#  'nature': 0.031949595288475324,
#  'tend': 0.0,
#  'support': 0.0,
#  'traditional': 0.02873712224657785,
#  'roles': 0.0,
#  'believing': 0.0,
#  'deference': 0.0,
#  'male': 0.0,
#  'authority': 0.0,
#  'figure': 0.0,
#  'husband': 0.0,
#  'faultless': 0.0,
#  'effectively': 0.0,
#  'takes': 0.0,
#  'autonomy': 0.0,
#  'away': 0.0,
#  'creating': 0.0,
#  'climate': 0.030181643795892305,
#  'explain': 0.0,
#  'performed': 0.0,
#  'poorly': 0.0,
#  'survey': 0.0,
#  'nbc': 0.0,
#  'wsj': 0.0,
#  'poll': 0.0,
#  '47': 0.0,
#  'voting': 0.0,
#  'favorability': 0.0,
#  'ratings': 0.0,
#  'higher': 0.0,
#  '59': 0.0,
#  'registered': 0.0,
#  'cnn': 0.0,
#  'orc': 0.0,
#  'ask': 0.0,
#  'intended': 0.0,
#  'vote': 0.06036328759178461,
#  'don_vito_08': 0.0,
#  'picture': 0.0,
#  'worth': 0.0,
#  'thousand': 0.03422888118486373,
#  'words': 0.0,
#  'lyingted': 0.0,
#  'nevercruz': 0.0,
#  'melaniatrump': 0.0,
#  '5bvvewmvf8': 0.0,
#  '24': 0.0,
#  'polls': 0.0,
#  'fully': 0.0,
#  'reflect': 0.0,
#  'unseemly': 0.0,
#  'attacks': 0.0,
#  'heidi': 0.0,
#  'cruz': 0.0,
#  'wife': 0.0,
#  'opponent': 0.0,
#  'sen': 0.0,
#  'ted': 0.0,
#  'abortion': 0.0,
#  'banned': 0.0,
#  'illegally': 0.0,
#  'face': 0.0,
#  'punishment': 0.0,
#  'clarified': 0.0,
#  'hypothetical': 0.0,
#  'reversed': 0.0,
#  'position': 0.0,
#  'clear': 0.027515796678896375,
#  'willing': 0.0,
#  'publicly': 0.0,
#  'embarrass': 0.0,
#  'degrade': 0.0,
#  'consider': 0.0,
#  'depriving': 0.0,
#  'physical': 0.0,
#  'freedom': 0.0,
#  'power': 0.0,
#  'dynamics': 0.0,
#  'aren': 0.024689884857606426,
#  'abusive': 0.0,
#  'workplaces': 0.0,
#  'relationships': 0.0,
#  'fathom': 0.0,
#  'mirrors': 0.0,
#  'private': 0.0,
#  'hell': 0.0,
#  'doing': 0.0,
#  'control': 0.0,
#  'elevate': 0.0,
#  'insulate': 0.0,
#  'attack': 0.0,
#  'jackie': 0.0,
#  'white': 0.0,
#  'emerita': 0.0,
#  'psychology': 0.0,
#  'senior': 0.0,
#  'research': 0.0,
#  'scientist': 0.0,
#  'center': 0.0,
#  'health': 0.0,
#  'wellness': 0.0,
#  'north': 0.0,
#  'carolina': 0.0,
#  'greensboro': 0.0,
#  'approach': 0.0,
#  'victimizes': 0.0,
#  'playing': 0.0,
#  'degradation': 0.0,
#  'manipulation': 0.0,
#  'present': 0.0,
#  'self': 0.0,
#  'assured': 0.0,
#  'knowledgable': 0.0,
#  'person': 0.0,
#  'silences': 0.0,
#  'depressed': 0.0,
#  'passive': 0.0,
#  'paralyzed': 0.0,
#  'feelings': 0.0,
#  'doubt': 0.0,
#  'insecurity': 0.0,
#  'set': 0.0,
#  'experience': 0.024689884857606426,
#  'worries': 0.0,
#  'tactics': 0.0,
#  'display': 0.0,
#  'consciously': 0.0,
#  'subconsciously': 0.0,
#  'lead': 0.0,
#  'endorse': 0.0,
#  'harmful': 0.0,
#  'stereotypes': 0.0,
#  'engage': 0.0,
#  'particularly': 0.0,
#  'threatened': 0.0,
#  'demographic': 0.0,
#  'change': 0.022611190267357657,
#  'evolving': 0.0,
#  'gender': 0.0,
#  'inspire': 0.0,
#  'justified': 0.0,
#  'clinging': 0.0,
#  'deserved': 0.0,
#  'elevated': 0.0,
#  'status': 0.0,
#  'makes': 0.0,
#  'offering': 0.0,
#  'public': 0.0,
#  'performance': 0.0,
#  'fallout': 0.0,
#  'unconscionable': 0.0,
#  'london': 0.0,
#  'month': 0.0,
#  'dog': 0.030181643795892305,
#  'sized': 0.0,
#  'rabbit': 0.0,
#  'desperate': 0.0,
#  'need': 0.0,
#  'atlas': 0.0,
#  'permanent': 0.0,
#  'story': 0.0,
#  'went': 0.0,
#  'global': 0.0,
#  'including': 0.0,
#  'canada': 0.0,
#  'france': 0.0,
#  'started': 0.0,
#  'reaching': 0.0,
#  'scottish': 0.0,
#  'society': 0.0,
#  'prevention': 0.0,
#  'cruelty': 0.0,
#  'animals': 0.0,
#  'thanks': 0.0,
#  'jen': 0.0,
#  'hislop': 0.0,
#  'ayrshire': 0.0,
#  'adorable': 0.0,
#  'bunny': 0.0,
#  'native': 0.0,
#  'scotland': 0.0,
#  'buggy': 0.0,
#  'facebook': 0.0,
#  'spcajen': 0.0,
#  'financial': 0.0,
#  'fraud': 0.0,
#  'investigator': 0.0,
#  'told': 0.0,
#  'charity': 0.0,
#  'burst': 0.0,
#  'tears': 0.0,
#  'got': 0.0,
#  'phone': 0.0,
#  'saying': 0.023934748652006916,
#  'chosen': 0.0,
#  'cried': 0.0,
#  'collected': 0.0,
#  '43': 0.024689884857606426,
#  'year': 0.0,
#  'old': 0.0,
#  'bunnies': 0.0,
#  'currently': 0.0,
#  'rex': 0.0,
#  'named': 0.0,
#  'coconut': 0.0,
#  'looking': 0.0,
#  'growing': 0.0,
#  'summer': 0.0,
#  'house': 0.0,
#  'heating': 0.0,
#  'air': 0.0,
#  'conditioning': 0.0,
#  'accommodation': 0.0,
#  'large': 0.0,
#  'garden': 0.0,
#  'enclosure': 0.0,
#  'run': 0.0,
#  'perfect': 0.0,
#  'addition': 0.0,
#  'family': 0.024689884857606426,
#  'thing': 0.02324536330829197,
#  'hello': 0.0,
#  'atilla': 0.0,
#  'bun': 0.0,
#  'binky': 0.0,
#  'master': 0.0,
#  'jazz': 0.0,
#  'paws': 0.0,
#  'worry': 0.0,
#  'atty': 0.0,
#  'short': 0.0,
#  'digital': 0.0,
#  'marketing': 0.0,
#  'experts': 0.0,
#  'diverse': 0.0,
#  'skill': 0.0,
#  'sophisticated': 0.0,
#  'grasp': 0.0,
#  'available': 0.024689884857606426,
#  'channels': 0.0,
#  'ability': 0.0,
#  'identify': 0.0,
#  'opportunities': 0.0,
#  'basic': 0.0,
#  'skills': 0.0,
#  'brilliant': 0.0,
#  'marketer': 0.0,
#  'possess': 0.0,
#  'balance': 0.0,
#  'critical': 0.0,
#  'creative': 0.0,
#  'thinking': 0.0,
#  'order': 0.0,
#  'drive': 0.0,
#  'measurable': 0.0,
#  'success': 0.0,
#  'asked': 0.0,
#  '15': 0.0,
#  'members': 0.0,
#  'young': 0.0,
#  'entrepreneur': 0.0,
#  'council': 0.0,
#  'yec': 0.0,
#  'hiring': 0.0,
#  'marketers': 0.0,
#  'best': 0.0,
#  'answers': 0.0,
#  'paid': 0.0,
#  'advertising': 0.0,
#  'expertise': 0.0,
#  'hire': 0.0,
#  'versed': 0.0,
#  'especially': 0.030181643795892305,
#  'similar': 0.0,
#  'platform': 0.03364083444899407,
#  'uses': 0.0,
#  'regularly': 0.0,
#  'able': 0.0,
#  'understand': 0.0,
#  'implement': 0.0,
#  'analytics': 0.0,
#  'insights': 0.0,
#  'create': 0.0,
#  'lookalike': 0.0,
#  'custom': 0.0,
#  'audiences': 0.0,
#  'experiment': 0.0,
#  'test': 0.0,
#  'images': 0.0,
#  'secure': 0.0,
#  'knowledge': 0.0,
#  'overall': 0.031949595288475324,
#  'landscape': 0.0,
#  'budget': 0.0,
#  'saving': 0.0,
#  'space': 0.0,
#  'sure': 0.0,
#  'talent': 0.0,
#  'knows': 0.0,
#  'ins': 0.0,
#  'outs': 0.0,
#  'popular': 0.027515796678896375,
#  'easy': 0.0,
#  'miles': 0.0,
#  'jennings': 0.0,
#  'recruiter': 0.0,
#  'web': 0.0,
#  'developers': 0.0,
#  'data': 0.0,
#  'scientists': 0.0,
#  'ai': 0.0,
#  'hired': 0.0,
#  'years': 0.0,
#  'outsourced': 0.0,
#  'successfully': 0.0,
#  'better': 0.0,
#  'turn': 0.0,
#  'closing': 0.0,
#  'deals': 0.0,
#  'directly': 0.0,
#  'sell': 0.0,
#  'll': 0.0,
#  'wasting': 0.0,
#  'valuable': 0.0,
#  'dollars': 0.031949595288475324,
#  'generating': 0.0,
#  'qualified': 0.0,
#  'team': 0.0,
#  'mark': 0.0,
#  'cenicola': 0.0,
#  'bannerview': 0.0,
#  'specific': 0.0,
#  'channel': 0.017119431329071774,
#  'extol': 0.0,
#  'conceivable': 0.0,
#  'seo': 0.0,
#  'sem': 0.0,
#  'key': 0.0,
#  'successful': 0.0,
#  'focusing': 0.0,
#  'really': 0.0,
#  'understanding': 0.0,
#  'deeply': 0.0,
#  'leveraging': 0.0,
#  'example': 0.0,
#  'helping': 0.0,
#  'local': 0.0,
#  'businesses': 0.0,
#  'pinterest': 0.0,
#  'interesting': 0.0,
#  'drivers': 0.0,
#  'ecommerce': 0.0,
#  'traffic': 0.0,
#  'focus': 0.0,
#  'intricate': 0.0,
#  'client': 0.0,
#  'google': 0.0,
#  'maps': 0.0,
#  'yelp': 0.0,
#  'trevor': 0.0,
#  'sumner': 0.0,
#  'localvox': 0.0,
#  'objectively': 0.0,
#  'usually': 0.0,
#  'passionate': 0.0,
#  'workers': 0.0,
#  'office': 0.0,
#  'passion': 0.0,
#  'cloud': 0.0,
#  'judgment': 0.0,
#  'measurement': 0.0,
#  'theories': 0.031949595288475324,
#  'initiatives': 0.0,
#  'separate': 0.0,
#  'navigate': 0.0,
#  'objective': 0.0,
#  'eye': 0.0,
#  'actually': 0.0,
#  'works': 0.0,
#  'hoped': 0.0,
#  'wesley': 0.0,
#  'mathews': 0.0,
#  'level': 0.0,
#  'execute': 0.0,
#  'analyze': 0.0,
#  'drip': 0.0,
#  'campaigns': 0.0,
#  'inbound': 0.0,
#  'driving': 0.0,
#  'generation': 0.0,
#  'come': 0.0,
#  'initial': 0.0,
#  'innovative': 0.0,
#  'engagement': 0.0,
#  'cpc': 0.0,
#  'intrigues': 0.0,
#  'examine': 0.0,
#  'incoming': 0.0,
#  'robust': 0.0,
#  'great': 0.0,
#  'automation': 0.0,
#  'sending': 0.0,
#  'flock': 0.0,
#  'gathers': 0.0,
#  'written': 0.0,
#  'communication': 0.0,
#  'varies': 0.0,
#  'depending': 0.0,
#  'seven': 0.0,
#  'emails': 0.0,
#  'deep': 0.0,
#  'lot': 0.0,
#  'variation': 0.0,
#  'requires': 0.0,
#  'analytical': 0.0,
#  'mindset': 0.0,
#  'strategic': 0.0,
#  'exceptional': 0.0,
#  'happens': 0.0,
#  'art': 0.0,
#  'expands': 0.0,
#  'fundamental': 0.0,
#  'conversion': 0.0,
#  'eran': 0.0,
#  'eyal': 0.0,
#  'springleap': 0.0,
#  '11': 0.0,
#  'things': 0.0,
#  'startup': 0.0,
#  'mix': 0.0,
#  'creativity': 0.0,
#  'abilities': 0.0,
#  'candidate': 0.052915672700378884,
#  'capable': 0.0,
#  'excited': 0.0,
#  'candidates': 0.030181643795892305,
#  'purely': 0.0,
#  'important': 0.0,
#  'bring': 0.0,
#  'program': 0.0,
#  'allows': 0.0,
#  'beautiful': 0.0,
#  'inform': 0.0,
#  'future': 0.0,
#  'strategies': 0.0,
#  'kayla': 0.0,
#  'wagner': 0.0,
#  'faires': 0.0,
#  'revel': 0.0,
#  'interactive': 0.0,
#  'good': 0.0,
#  'copy': 0.0,
#  'visual': 0.0,
#  'storytelling': 0.0,
#  'driven': 0.0,
#  'medium': 0.0,
#  'unlike': 0.0,
#  'heart': 0.0,
#  'won': 0.09573899460802766,
#  'double': 0.0,
#  'clicked': 0.0,
#  'relevant': 0.0,
#  'visuals': 0.0,
#  'pull': 0.0,
#  'strings': 0.0,
#  'manipulate': 0.0,
#  'elements': 0.0,
#  'alex': 0.0,
#  'frias': 0.0,
#  'likable': 0.0,
#  'personality': 0.0,
#  'building': 0.0,
#  'huge': 0.0,
#  'component': 0.0,
#  'trying': 0.0,
#  'connect': 0.0,
#  'bloggers': 0.0,
#  'influencers': 0.0,
#  'stand': 0.0,
#  'command': 0.0,
#  'attention': 0.0,
#  'pitched': 0.0,
#  'equivalent': 0.0,
#  'talking': 0.0,
#  'brick': 0.0,
#  'wall': 0.0,
#  'outgoing': 0.0,
#  'pleasant': 0.0,
#  'applies': 0.0,
#  'maintaining': 0.0,
#  'plays': 0.0,
#  'overlooked': 0.0,
#  'jonathan': 0.0,
#  'domination': 0.0,
#  '14': 0.0,
#  'mobile': 0.0,
#  'trends': 0.0,
#  'dominate': 0.0,
#  'wordpress': 0.0,
#  'platforms': 0.0,
#  'built': 0.0,
#  'vital': 0.0,
#  'technical': 0.0,
#  'tool': 0.0,
#  'add': 0.0,
#  'toolbox': 0.0,
#  'manage': 0.0,
#  'blog': 0.0,
#  'website': 0.0,
#  'helps': 0.0,
#  'continually': 0.0,
#  'educate': 0.0,
#  'plug': 0.0,
#  'functionality': 0.0,
#  'useful': 0.0,
#  'speeds': 0.0,
#  'content': 0.0,
#  'production': 0.0,
#  'angela': 0.0,
#  ...}

# %%
# print words with the top 5 TF-IDF scores
print('TOP SCORING WORDS:')
top_scores = sorted(word_scores.items(), key=lambda x: x[1], reverse=True)[:5]
for word, score in top_scores:
    print(word)
# Out:
# TOP SCORING WORDS:
# sanders
# iowa
# precinct
# coin
# des

# %%
# print 5 random words
print('\n' + 'RANDOM WORDS:')
random_words = np.random.choice(list(word_scores.keys()), size=5, replace=False)
for word in random_words:
    print(word)
# Out:
# RANDOM WORDS:
# casually
# coconut
# discrediting
# slam
# regularly

# %% [markdown]
# # Conclusion
#
# - NLP is a gigantic field
# - Understanding the basics broadens the types of data you can work with
# - Simple techniques go a long way
# - Use scikit-learn for NLP whenever possible
