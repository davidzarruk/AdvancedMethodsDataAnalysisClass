# %% [markdown]
# # Exercise 13
#
# The result will be evaluated from a report in Jupyter, which must be found in a public GitHub repository. The project must be carried out in the groups assigned in class. Use clear and rigorous procedures. Due date: July 29, 2021, 11:59 am (NOON), through Bloque Neón + (Upload repository link).
#
# ## Analyze class homeworks

# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

data = pd.read_excel('../datasets/Consolidado_respuestas_escribir_v2.xlsx')
data.head()
# Out:
#    ID Genero Carrera de pregrado Sector en el que trabaja  Edad  \
# 0   1      M         Matemáticas      Estudio de mercados  30.0
# 1   2      M                 NaN                      NaN   NaN
# 2   3      M                 NaN                      NaN   NaN
# 3   4      M         Estadistica               Financiero  28.0
# 4   5      M                 NaN                      NaN   NaN
#
#                E1 - Examples of Time Series Analysis  \
# 0  Dentro de las diferentes aplicaciones que tien...
# 1                                                NaN
# 2  Mercados energeticos: Tras la liberación y des...
# 3  Las series de tiempo son una colección de obse...
# 4  1. Actualmente, la empresa de mascotas Laika q...
#
#                                      E4 - Panel Data  \
# 0  La principal diferencia entre las series de ti...
# 1  una serie de tiempo se enfoca en un individio ...
# 2  Los datos de series de tiempo son un conjunto ...
# 3  Los datos de series de tiempo son un conjunto ...
# 4  Un conjunto de datos de una serie de tiempo co...
#
#                                   E6 - Decison Trees  \
# 0  Los arboles de decisión son herramienta de Mac...
# 1                                                NaN
# 2                                                NaN
# 3  Un árbol de decisión es una especie de mapa en...
# 4                                                NaN
#
#                         E8 - Ensemble Trees Overview  \
# 0  Al proponer un método para realizar una predic...
# 1                                                NaN
# 2  Los metodos de ensamble nos permiten mejorar e...
# 3  Los métodos de ensamble de modelos o métodos c...
# 4  Los modelos de ensamble consisten en mezclar l...
#
#                                       E10 - REST-API  \
# 0  Durante el desarrollo de soluciones dentro de ...
# 1  Un micro servicio es una parte de la arquitect...
# 2  Los microservicios defininen una nueva metodol...
# 3  Los microservicios son tanto un estilo de arqu...
# 4  Los microservicios son tanto un estilo de arqu...
#
#           E12 - Natural Language Processing Overview
# 0  La empresa kore.ai se especializa en la implem...
# 1                                                NaN
# 2                                                NaN
# 3  La función de autocompletar las palabras en Wh...
# 4                                                NaN

# %% [markdown]
# # Exercise 13.1
#
# Analyze the writing patterns of each student

# %% [markdown]
# # Exercise 13.2
#
# Create a classifier to predict the gender of each student

# %% [markdown]
# # Exercise 13.3
#
# Create a classifier to predict the industry in which each student works
